# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Exploración-del-dataframe" data-toc-modified-id="Exploración-del-dataframe-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Exploración del dataframe</a></span></li><li><span><a href="#Otros-métodos-interesantes" data-toc-modified-id="Otros-métodos-interesantes-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Otros métodos interesantes</a></span><ul class="toc-item"><li><span><a href="#replace()" data-toc-modified-id="replace()-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span><code>replace()</code></a></span></li><li><span><a href="#np.where()" data-toc-modified-id="np.where()-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span><code>np.where()</code></a></span></li><li><span><a href="#sort_values()" data-toc-modified-id="sort_values()-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span><code>sort_values()</code></a></span></li></ul></li><li><span><a href="#loc-e-iloc" data-toc-modified-id="loc-e-iloc-3"><span class="toc-item-num">3&nbsp;&nbsp;</span><code>loc</code> e <code>iloc</code></a></span><ul class="toc-item"><li><span><a href="#loc" data-toc-modified-id="loc-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span><code>loc</code></a></span></li><li><span><a href="#iloc" data-toc-modified-id="iloc-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span><code>iloc</code></a></span></li></ul></li><li><span><a href="#Apply" data-toc-modified-id="Apply-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Apply</a></span></li><li><span><a href="#Groupby" data-toc-modified-id="Groupby-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Groupby</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
import datetime

pd.options.display.max_columns = None

# %% [markdown]
# **Herramientas útiles de Python**
#
# 📌 En Python tenemos una serie de librerias que nos van a proveer de datasets para que nosotros podamos trabajar. En este caso usaremos la librería PyDataset
#
# 1️⃣ Lo primero que tenemos que hacer es instalarla desde la terminal
#
# ```
# pip install pydataset
# ```
# o
# ```
# pip3 install pydataset
# ```
#
# 2️⃣ Una vez instalado lo importamos en nuestro jupyter:
#
# ```python
# from pydataset import data
# ```

# %%
# recordamos que podemos instalar librerías de pandas desde jupyter usando !
# !pip install pydataset

# %%
# importamos la librería
from pydataset import data

# %%
# para saber que datasets tenemos 
datasets = data()
datasets.sample(10)
# Out:
#       dataset_id  \
# 367        crohn
# 388    Cavendish
# 633  newpainters
# 369        fsnps
# 381       movies
# 44       longley
# 474       forbes
# 456        beav1
# 41          iris
# 674   toothpaste
#
#                                                              title
# 367                                           Crohn's disease data
# 388         Cavendish's Determinations of the Density of the Earth
# 633                     The Discretized Painter's Data of de Piles
# 369  A case-control data involving four SNPs with missing genotype
# 381              Movie information and user ratings from IMDB.com.
# 44                              Longley's Economic Regression Data
# 474                     Forbes' Data on Boiling Points in the Alps
# 456                            Body Temperature Series of Beaver 1
# 41                                      Edgar Anderson's Iris Data
# 674                                                Toothpaste Data

# %%
# cargamos el dataframe con el que queremos trabajar

df_cbpp = data("cbpp")
df_cbpp.head()
# Out:
#    herd  incidence  size  period
# 1     1          2    14       1
# 2     1          3    12       2
# 3     1          4     9       3
# 4     1          0     5       4
# 5     2          3    22       1

# %% [markdown]
# # Exploración del dataframe

# %% [markdown]
# En este jupyter trabajaremos con este dataframe

# %%
# cargamos el dataset
df = pd.read_csv("datos/retail.csv")
df.head()
# Out:
#    invoiceno                 invoicedate stockcode  \
# 0     536365  2010-12-01 08:26:00.000000    85123A
# 1     536373  2010-12-01 09:02:00.000000    85123A
# 2     536375  2010-12-01 09:32:00.000000    85123A
# 3     536390  2010-12-01 10:19:00.000000    85123A
# 4     536394  2010-12-01 10:39:00.000000    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        68       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        36       2.55     81.6
#
#    customerid         country  nullid
# 0       17850  United Kingdom     NaN
# 1       17850  United Kingdom     1.0
# 2       17850  United Kingdom     NaN
# 3       17511  United Kingdom     3.0
# 4       13408  United Kingdom     NaN

# %%
# cuántas filas y columnas tenemos?
df.shape
# Out:
# (396034, 10)

# %%
# pequeño resumen de los datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    396034 non-null  int64
#  1   invoicedate  396034 non-null  object
#  2   stockcode    396034 non-null  object
#  3   description  396034 non-null  object
#  4   quantity     396034 non-null  int64
#  5   unitprice    396034 non-null  float64
#  6   revenue      396034 non-null  float64
#  7   customerid   396034 non-null  int64
#  8   country      396034 non-null  object
#  9   nullid       198017 non-null  float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 30.2+ MB

# %%
df.describe()
# Out:
#            invoiceno       quantity      unitprice        revenue  \
# count  396034.000000  396034.000000  396034.000000  396034.000000
# mean   560620.294401      13.259632       2.867826      21.492062
# std     13110.655964      16.960865       4.265226      93.863439
# min    536365.000000    -124.000000       0.040000       0.060000
# 25%    549198.500000       6.000000       1.250000       4.680000
# 50%    561894.000000       9.000000       1.950000      11.800000
# 75%    572095.000000      16.000000       3.750000      19.800000
# max    581587.000000     130.000000     649.500000   38970.000000
#
#           customerid         nullid
# count  396034.000000  198017.000000
# mean    15302.695435  198017.000000
# std      1709.744925  114325.456929
# min     12347.000000       1.000000
# 25%     13975.000000   99009.000000
# 50%     15160.000000  198017.000000
# 75%     16805.000000  297025.000000
# max     18287.000000  396033.000000

# %%
# que tipos de datos tenemos en nuestras columnas?
df.dtypes
# Out:
# invoiceno        int64
# invoicedate     object
# stockcode       object
# description     object
# quantity         int64
# unitprice      float64
# revenue        float64
# customerid       int64
# country         object
# nullid         float64
# dtype: object

# %%
# cuántos valores nulos tenemos?
df.isna().sum()
# Out:
# invoiceno           0
# invoicedate         0
# stockcode           0
# description         0
# quantity            0
# unitprice           0
# revenue             0
# customerid          0
# country             0
# nullid         198017
# dtype: int64

# %% [markdown]
# # Otros métodos interesantes

# %% [markdown]
# ## `replace()`
#
# Reemplaza ciertos valores de nuestro dataframe por otro valor que nosotros especifiquemos.
#
# ```python
# MiDataframe.replace(to_replace, value, inplace)
# ```
#
# Donde:
#
# - `to_replace`: es el valor que queremos reemplazar
#
#
# - `value`: el valor nuevo que queremos incluir
#
#
# - `inplace`: para que los cambios se ejecuten sobre el dataframe orginal.

# %%
# recordemos el dataset
df.head()
# Out:
#    invoiceno                 invoicedate stockcode  \
# 0     536365  2010-12-01 08:26:00.000000    85123A
# 1     536373  2010-12-01 09:02:00.000000    85123A
# 2     536375  2010-12-01 09:32:00.000000    85123A
# 3     536390  2010-12-01 10:19:00.000000    85123A
# 4     536394  2010-12-01 10:39:00.000000    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        68       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        36       2.55     81.6
#
#    customerid         country  nullid
# 0       17850  United Kingdom     NaN
# 1       17850  United Kingdom     1.0
# 2       17850  United Kingdom     NaN
# 3       17511  United Kingdom     3.0
# 4       13408  United Kingdom     NaN

# %%
# vamos a reemplazar los valores nulos por la media de los valores de la columna

df["nullid"].replace(np.nan, df["nullid"].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# invoiceno      0
# invoicedate    0
# stockcode      0
# description    0
# quantity       0
# unitprice      0
# revenue        0
# customerid     0
# country        0
# nullid         0
# dtype: int64

# %%
df.head()
# Out:
#    invoiceno                 invoicedate stockcode  \
# 0     536365  2010-12-01 08:26:00.000000    85123A
# 1     536373  2010-12-01 09:02:00.000000    85123A
# 2     536375  2010-12-01 09:32:00.000000    85123A
# 3     536390  2010-12-01 10:19:00.000000    85123A
# 4     536394  2010-12-01 10:39:00.000000    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        68       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        36       2.55     81.6
#
#    customerid         country    nullid
# 0       17850  United Kingdom  198017.0
# 1       17850  United Kingdom       1.0
# 2       17850  United Kingdom  198017.0
# 3       17511  United Kingdom       3.0
# 4       13408  United Kingdom  198017.0

# %% [markdown]
# ## `np.where()`
#
# La sintaxis que seguiremos en este método es:
#
# ```python
# MiDataframe.where(cond, true, false)
# ```
#
# Donde:
#
# - `cond`: es una condición que nosotros querramos que cumpla el dataframe.
#
#
# - `true`: es el valor que queremos que se reemplace en el dataframe cuando SI se cumpla la condición.
#
#
# - `false`: es el valor que queremos que se reemplace en el dataframe cuando NO se cumpla la condición.

# %%
# establecemos la condición

df["desciption_cambiada"] = np.where(df["description"] == "CREAM HANGING HEART T-LIGHT HOLDER", 1, 2)

# %%
# si nos fijamos en la nueva columna, tendremos valores de 1 donde se cumpla la cumpla la condición y 2 donde no. 
df.sample(5)
# Out:
#         invoiceno                 invoicedate stockcode  \
# 118587     573581  2011-10-31 14:22:00.000000     22909
# 215131     556779  2011-06-14 12:45:00.000000    47566B
# 327403     552039  2011-05-06 08:10:00.000000     23206
# 178223     579132  2011-11-28 12:34:59.999999     22600
# 286343     544792  2011-02-23 12:37:00.000000     85053
#
#                                 description  quantity  unitprice  revenue  \
# 118587  SET OF 20 VINTAGE CHRISTMAS NAPKINS        16       0.85     10.2
# 215131               TEA TIME PARTY BUNTING         6       4.95      9.9
# 327403               LUNCH BAG APPLE DESIGN        24       1.65     33.0
# 178223        CHRISTMAS RETROSPOT STAR WOOD         8       0.85      3.4
# 286343           FRENCH ENAMEL CANDLEHOLDER        10       2.10     12.6
#
#         customerid         country    nullid  desciption_cambiada
# 118587       14911            EIRE  118587.0                    2
# 215131       16774  United Kingdom  215131.0                    2
# 327403       13081  United Kingdom  327403.0                    2
# 178223       15022  United Kingdom  178223.0                    2
# 286343       18172  United Kingdom  286343.0                    2

# %%
df[df["desciption_cambiada"] == 1]
# Out:
#       invoiceno                 invoicedate stockcode  \
# 0        536365  2010-12-01 08:26:00.000000    85123A
# 1        536373  2010-12-01 09:02:00.000000    85123A
# 2        536375  2010-12-01 09:32:00.000000    85123A
# 3        536390  2010-12-01 10:19:00.000000    85123A
# 4        536394  2010-12-01 10:39:00.000000    85123A
# ...         ...                         ...       ...
# 2030     581412  2011-12-08 14:38:00.000000    85123A
# 2031     581432  2011-12-08 15:51:00.000001    85123A
# 2032     581452  2011-12-08 18:03:00.000000    85123A
# 2033     581472  2011-12-08 19:55:00.000000    85123A
# 2034     581538  2011-12-09 11:33:59.999999    85123A
#
#                              description  quantity  unitprice  revenue  \
# 0     CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 1     CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 2     CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 3     CREAM HANGING HEART T-LIGHT HOLDER        68       2.55   163.20
# 4     CREAM HANGING HEART T-LIGHT HOLDER        36       2.55    81.60
# ...                                  ...       ...        ...      ...
# 2030  CREAM HANGING HEART T-LIGHT HOLDER         8       2.95    11.80
# 2031  CREAM HANGING HEART T-LIGHT HOLDER        36       2.55    81.60
# 2032  CREAM HANGING HEART T-LIGHT HOLDER        36       2.55    81.60
# 2033  CREAM HANGING HEART T-LIGHT HOLDER        10       2.95    17.70
# 2034  CREAM HANGING HEART T-LIGHT HOLDER         5       2.95     2.95
#
#       customerid         country    nullid  desciption_cambiada
# 0          17850  United Kingdom  198017.0                    1
# 1          17850  United Kingdom       1.0                    1
# 2          17850  United Kingdom  198017.0                    1
# 3          17511  United Kingdom       3.0                    1
# 4          13408  United Kingdom  198017.0                    1
# ...          ...             ...       ...                  ...
# 2030       14415  United Kingdom  198017.0                    1
# 2031       13798  United Kingdom    2031.0                    1
# 2032       17675  United Kingdom  198017.0                    1
# 2033       15796  United Kingdom    2033.0                    1
# 2034       14446  United Kingdom  198017.0                    1
#
# [2035 rows x 11 columns]

# %% [markdown]
# ## `sort_values()`
#
# Ordena los valores de un dataframe en función de la columna que especifiquemos.
#
# 📌 Por defecto ordena de menor a mayor. En caso de que queramos ordenar de mayor a menior, debemos especificar el parámetro `ascending=False`

# %%
# ordenamos de menor a mayor por la columna de unitprice
df.sort_values(by = ["invoiceno"]).head(10)
# Out:
#       invoiceno                 invoicedate stockcode  \
# 0        536365  2010-12-01 08:26:00.000000    85123A
# 3196     536365  2010-12-01 08:26:00.000000     22752
# 2035     536365  2010-12-01 08:26:00.000000     71053
# 3495     536365  2010-12-01 08:26:00.000000     21730
# 2298     536365  2010-12-01 08:26:00.000000    84406B
# 2868     536365  2010-12-01 08:26:00.000000    84029E
# 2542     536365  2010-12-01 08:26:00.000000    84029G
# 4085     536366  2010-12-01 08:28:00.000000     22632
# 3615     536366  2010-12-01 08:28:00.000000     22633
# 4457     536367  2010-12-01 08:33:59.999999     84879
#
#                               description  quantity  unitprice  revenue  \
# 0      CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 3196         SET 7 BABUSHKA NESTING BOXES         6       7.65    15.30
# 2035                  WHITE METAL LANTERN        10       3.39    20.34
# 3495    GLASS STAR FROSTED T-LIGHT HOLDER        10       4.25    25.50
# 2298       CREAM CUPID HEARTS COAT HANGER        12       2.75    22.00
# 2868       RED WOOLLY HOTTIE WHITE HEART.        10       3.39    20.34
# 2542  KNITTED UNION FLAG HOT WATER BOTTLE        10       3.39    20.34
# 4085            HAND WARMER RED POLKA DOT        10       1.85    11.10
# 3615               HAND WARMER UNION JACK        10       1.85    11.10
# 4457        ASSORTED COLOUR BIRD ORNAMENT        36       1.69    54.08
#
#       customerid         country    nullid  desciption_cambiada
# 0          17850  United Kingdom  198017.0                    1
# 3196       17850  United Kingdom  198017.0                    2
# 2035       17850  United Kingdom    2035.0                    2
# 3495       17850  United Kingdom    3495.0                    2
# 2298       17850  United Kingdom  198017.0                    2
# 2868       17850  United Kingdom  198017.0                    2
# 2542       17850  United Kingdom  198017.0                    2
# 4085       17850  United Kingdom    4085.0                    2
# 3615       17850  United Kingdom    3615.0                    2
# 4457       13047  United Kingdom    4457.0                    2

# %%
# incluso podemos ordenar por dos columnas
df.sort_values(by = ["invoiceno", "quantity"]).head(10)
# Out:
#       invoiceno                 invoicedate stockcode  \
# 3196     536365  2010-12-01 08:26:00.000000     22752
# 0        536365  2010-12-01 08:26:00.000000    85123A
# 2035     536365  2010-12-01 08:26:00.000000     71053
# 2542     536365  2010-12-01 08:26:00.000000    84029G
# 2868     536365  2010-12-01 08:26:00.000000    84029E
# 3495     536365  2010-12-01 08:26:00.000000     21730
# 2298     536365  2010-12-01 08:26:00.000000    84406B
# 3615     536366  2010-12-01 08:28:00.000000     22633
# 4085     536366  2010-12-01 08:28:00.000000     22632
# 7313     536367  2010-12-01 08:33:59.999999     22622
#
#                               description  quantity  unitprice  revenue  \
# 3196         SET 7 BABUSHKA NESTING BOXES         6       7.65    15.30
# 0      CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 2035                  WHITE METAL LANTERN        10       3.39    20.34
# 2542  KNITTED UNION FLAG HOT WATER BOTTLE        10       3.39    20.34
# 2868       RED WOOLLY HOTTIE WHITE HEART.        10       3.39    20.34
# 3495    GLASS STAR FROSTED T-LIGHT HOLDER        10       4.25    25.50
# 2298       CREAM CUPID HEARTS COAT HANGER        12       2.75    22.00
# 3615               HAND WARMER UNION JACK        10       1.85    11.10
# 4085            HAND WARMER RED POLKA DOT        10       1.85    11.10
# 7313       BOX OF VINTAGE ALPHABET BLOCKS         6       9.95    19.90
#
#       customerid         country    nullid  desciption_cambiada
# 3196       17850  United Kingdom  198017.0                    2
# 0          17850  United Kingdom  198017.0                    1
# 2035       17850  United Kingdom    2035.0                    2
# 2542       17850  United Kingdom  198017.0                    2
# 2868       17850  United Kingdom  198017.0                    2
# 3495       17850  United Kingdom    3495.0                    2
# 2298       17850  United Kingdom  198017.0                    2
# 3615       17850  United Kingdom    3615.0                    2
# 4085       17850  United Kingdom    4085.0                    2
# 7313       13047  United Kingdom    7313.0                    2

# %%
# si lo queremos hacer de mayor a menos
df.sort_values(by = ["invoiceno"], ascending = False).head(20)
# Out:
#         invoiceno                 invoicedate stockcode  \
# 324311     581587  2011-12-09 12:50:00.000000     23254
# 123771     581587  2011-12-09 12:50:00.000000     22367
# 15406      581587  2011-12-09 12:50:00.000000     22629
# 324641     581587  2011-12-09 12:50:00.000000     23256
# 11456      581587  2011-12-09 12:50:00.000000     22728
# 281149     581587  2011-12-09 12:50:00.000000     22613
# 305071     581587  2011-12-09 12:50:00.000000     22138
# 16197      581587  2011-12-09 12:50:00.000000     22631
# 123314     581587  2011-12-09 12:50:00.000000     22899
# 168577     581587  2011-12-09 12:50:00.000000     22555
# 12354      581587  2011-12-09 12:50:00.000000     22727
# 13162      581587  2011-12-09 12:50:00.000000     22726
# 70407      581587  2011-12-09 12:50:00.000000     22730
# 324786     581587  2011-12-09 12:50:00.000000     23255
# 168116     581587  2011-12-09 12:50:00.000000     22556
# 352256     581586  2011-12-09 12:49:00.000000     23275
# 211123     581586  2011-12-09 12:49:00.000000     21217
# 244123     581586  2011-12-09 12:49:00.000000     22061
# 100514     581586  2011-12-09 12:49:00.000000     20685
# 229599     581585  2011-12-09 12:31:00.000000     84946
#
#                                 description  quantity  unitprice  revenue  \
# 324311        CHILDRENS CUTLERY DOLLY GIRL          8       4.15    16.60
# 123771      CHILDRENS APRON SPACEBOY DESIGN        12       1.95    15.60
# 15406                   SPACEBOY LUNCH BOX         16       1.95    23.40
# 324641          CHILDRENS CUTLERY SPACEBOY          8       4.15    16.60
# 11456             ALARM CLOCK BAKELIKE PINK         8       3.75    15.00
# 281149          PACK OF 20 SPACEBOY NAPKINS        16       0.85    10.20
# 305071        BAKING SET 9 PIECE RETROSPOT          7       4.95    14.85
# 16197              CIRCUS PARADE LUNCH BOX         16       1.95    23.40
# 123314         CHILDREN'S APRON DOLLY GIRL         10       2.10    12.60
# 168577            PLASTERS IN TIN STRONGMAN        16       1.65    19.80
# 12354             ALARM CLOCK BAKELIKE RED          8       3.75    15.00
# 13162            ALARM CLOCK BAKELIKE GREEN         8       3.75    15.00
# 70407            ALARM CLOCK BAKELIKE IVORY         8       3.75    15.00
# 324786      CHILDRENS CUTLERY CIRCUS PARADE         8       4.15    16.60
# 168116       PLASTERS IN TIN CIRCUS PARADE         16       1.65    19.80
# 352256     SET OF 3 HANGING OWLS OLLIE BEAK        28       1.25    30.00
# 211123        RED RETROSPOT ROUND CAKE TINS        28       8.95   214.80
# 244123  LARGE CAKE STAND  HANGING STRAWBERY        12       2.95    23.60
# 100514                DOORMAT RED RETROSPOT        14       7.08    70.80
# 229599         ANTIQUE SILVER T-LIGHT GLASS        16       1.25    15.00
#
#         customerid         country    nullid  desciption_cambiada
# 324311       12680          France  324311.0                    2
# 123771       12680          France  123771.0                    2
# 15406        12680          France  198017.0                    2
# 324641       12680          France  324641.0                    2
# 11456        12680          France  198017.0                    2
# 281149       12680          France  281149.0                    2
# 305071       12680          France  305071.0                    2
# 16197        12680          France   16197.0                    2
# 123314       12680          France  198017.0                    2
# 168577       12680          France  168577.0                    2
# 12354        12680          France  198017.0                    2
# 13162        12680          France  198017.0                    2
# 70407        12680          France   70407.0                    2
# 324786       12680          France  198017.0                    2
# 168116       12680          France  198017.0                    2
# 352256       13113  United Kingdom  198017.0                    2
# 211123       13113  United Kingdom  211123.0                    2
# 244123       13113  United Kingdom  244123.0                    2
# 100514       13113  United Kingdom  198017.0                    2
# 229599       15804  United Kingdom  229599.0                    2

# %%
df.sort_values(by = ["invoiceno"], ascending = False).sort_values(by = ["quantity"])
# Out:
#         invoiceno                 invoicedate stockcode  \
# 192708     570408  2011-10-10 12:59:00.000000     22065
# 15643      552888  2011-05-12 10:23:00.000000     22659
# 174475     567458  2011-09-20 12:21:00.000000     82600
# 149909     569408  2011-10-04 09:26:00.000001     22575
# 15573      547419  2011-03-23 10:27:00.000000     22659
# ...           ...                         ...       ...
# 382850     574352  2011-11-04 10:38:00.000000     23406
# 390390     574352  2011-11-04 10:38:00.000000     23530
# 390074     574352  2011-11-04 10:38:00.000000     23526
# 384138     581457  2011-12-08 18:43:00.000000     23401
# 390113     581457  2011-12-08 18:43:00.000000     23526
#
#                            description  quantity  unitprice  revenue  \
# 192708  CHRISTMAS PUDDING TRINKET POT       -124       0.39   149.76
# 15643          LUNCH BOX I LOVE LONDON      -124       1.65   211.20
# 174475           N0 SINGING METAL SIGN      -124       2.41   925.44
# 149909    METAL MERRY CHRISTMAS WREATH      -124       1.65   211.20
# 15573          LUNCH BOX I LOVE LONDON      -124       1.65   211.20
# ...                                ...       ...        ...      ...
# 382850      HOME SWEET HOME KEY HOLDER       130       4.15   522.90
# 390390       WALL ART ONLY ONE PERSON        130       3.57   449.82
# 390074            DOG LICENCE WALL ART       130       3.88   488.88
# 384138   RUSTIC MIRROR WITH LACE HEART       130       4.15   522.90
# 390113            DOG LICENCE WALL ART       130       3.90   491.40
#
#         customerid         country    nullid  desciption_cambiada
# 192708       13685  United Kingdom  198017.0                    2
# 15643        15061  United Kingdom   15643.0                    2
# 174475       17450  United Kingdom  174475.0                    2
# 149909       13881  United Kingdom  149909.0                    2
# 15573        15061  United Kingdom   15573.0                    2
# ...            ...             ...       ...                  ...
# 382850       18102  United Kingdom  198017.0                    2
# 390390       18102  United Kingdom  198017.0                    2
# 390074       18102  United Kingdom  198017.0                    2
# 384138       18102  United Kingdom  198017.0                    2
# 390113       18102  United Kingdom  390113.0                    2
#
# [396034 rows x 11 columns]

# %% [markdown]
# # `loc` e `iloc`

# %% [markdown]
# Las principales diferencias entre `loc` y `iloc` es:
#
#
# - `loc` se basa en etiquetas, lo que significa que tiene que especificar filas y columnas en función de sus etiquetas de fila y columna.
#
#
# - `iloc`:  se basa en la posición de los enteros, por lo que hay que especificar las filas y las columnas por sus valores de posición de los enteros (los índices)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.head(2)
# Out:
#    invoiceno                 invoicedate stockcode  \
# 0     536365  2010-12-01 08:26:00.000000    85123A
# 1     536373  2010-12-01 09:02:00.000000    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
#
#    customerid         country    nullid  desciption_cambiada
# 0       17850  United Kingdom  198017.0                    1
# 1       17850  United Kingdom       1.0                    1

# %%
# antes de empezar, para entender mejor esta parte vamos a poner la 
## columna "customerid" como índice

df.set_index(["customerid"], inplace = True)

# %% [markdown]
# ## `loc`
#
# Accede a través de las etiquetas (de los nombres de filas o columnas). Para usar este método tendremos que seguir la siguiente sintaxis:
#
# ```python
# loc[nombre_fila, nombre_columna]
# ```

# %%
# chequeamos las columnas que tenemos

df.columns
# Out:
# Index(['invoiceno', 'invoicedate', 'stockcode', 'description', 'quantity',
#        'unitprice', 'revenue', 'country', 'nullid', 'desciption_cambiada'],
#       dtype='object')

# %%
df.head(2)
# Out:
#             invoiceno                 invoicedate stockcode  \
# customerid
# 17850          536365  2010-12-01 08:26:00.000000    85123A
# 17850          536373  2010-12-01 09:02:00.000000    85123A
#
#                                    description  quantity  unitprice  revenue  \
# customerid
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
#
#                    country    nullid  desciption_cambiada
# customerid
# 17850       United Kingdom  198017.0                    1
# 17850       United Kingdom       1.0                    1

# %%
# seleccionamos las filas qdel cliente 17850 y toda la columna de la descripción de los productos que ha comprado

df.loc[17850, "description"]
# Out:
# customerid
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
#                         ...
# 17850              IVORY EMBROIDERED QUILT
# 17850              IVORY EMBROIDERED QUILT
# 17850              IVORY EMBROIDERED QUILT
# 17850              IVORY EMBROIDERED QUILT
# 17850              IVORY EMBROIDERED QUILT
# Name: description, Length: 297, dtype: object

# %%
serie = df.loc[17850, "description"]
serie
# Out:
# customerid
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
#                         ...
# 17850              IVORY EMBROIDERED QUILT
# 17850              IVORY EMBROIDERED QUILT
# 17850              IVORY EMBROIDERED QUILT
# 17850              IVORY EMBROIDERED QUILT
# 17850              IVORY EMBROIDERED QUILT
# Name: description, Length: 297, dtype: object

# %%
serie[17850]
# Out:
# customerid
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
#                         ...
# 17850              IVORY EMBROIDERED QUILT
# 17850              IVORY EMBROIDERED QUILT
# 17850              IVORY EMBROIDERED QUILT
# 17850              IVORY EMBROIDERED QUILT
# 17850              IVORY EMBROIDERED QUILT
# Name: description, Length: 297, dtype: object

# %%
pd.DataFrame(serie).reset_index()
# Out:
#      customerid                         description
# 0         17850  CREAM HANGING HEART T-LIGHT HOLDER
# 1         17850  CREAM HANGING HEART T-LIGHT HOLDER
# 2         17850  CREAM HANGING HEART T-LIGHT HOLDER
# 3         17850  CREAM HANGING HEART T-LIGHT HOLDER
# 4         17850  CREAM HANGING HEART T-LIGHT HOLDER
# ..          ...                                 ...
# 292       17850            IVORY EMBROIDERED QUILT
# 293       17850            IVORY EMBROIDERED QUILT
# 294       17850            IVORY EMBROIDERED QUILT
# 295       17850            IVORY EMBROIDERED QUILT
# 296       17850            IVORY EMBROIDERED QUILT
#
# [297 rows x 2 columns]

# %%
# dame toda la información del cliente "17850"
df.loc[17850,:]
# Out:
#             invoiceno                 invoicedate stockcode  \
# customerid
# 17850          536365  2010-12-01 08:26:00.000000    85123A
# 17850          536373  2010-12-01 09:02:00.000000    85123A
# 17850          536375  2010-12-01 09:32:00.000000    85123A
# 17850          536396  2010-12-01 10:51:00.000000    85123A
# 17850          536406  2010-12-01 11:33:00.000000    85123A
# ...               ...                         ...       ...
# 17850          536685  2010-12-02 12:23:00.000000     22803
# 17850          536690  2010-12-02 12:25:00.000000     22803
# 17850          536750  2010-12-02 14:04:00.000000     22803
# 17850          536752  2010-12-02 14:06:00.000000     22803
# 17850          536790  2010-12-02 15:26:00.000001     22803
#
#                                    description  quantity  unitprice  revenue  \
# customerid
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        12       2.55    20.40
# ...                                        ...       ...        ...      ...
# 17850                 IVORY EMBROIDERED QUILT          6      35.75    71.50
# 17850                 IVORY EMBROIDERED QUILT          6      35.75    71.50
# 17850                 IVORY EMBROIDERED QUILT          6      35.75    71.50
# 17850                 IVORY EMBROIDERED QUILT          6      35.75    71.50
# 17850                 IVORY EMBROIDERED QUILT          7      35.75   107.25
#
#                    country    nullid  desciption_cambiada
# customerid
# 17850       United Kingdom  198017.0                    1
# 17850       United Kingdom       1.0                    1
# 17850       United Kingdom  198017.0                    1
# 17850       United Kingdom       5.0                    1
# 17850       United Kingdom       7.0                    1
# ...                    ...       ...                  ...
# 17850       United Kingdom  198017.0                    2
# 17850       United Kingdom   71267.0                    2
# 17850       United Kingdom  198017.0                    2
# 17850       United Kingdom   71269.0                    2
# 17850       United Kingdom  198017.0                    2
#
# [297 rows x 10 columns]

# %% [markdown]
# También lo podemos hacer hacer con varias filas o columnas

# %%
# para varias filas
df.loc[[17850, 17511], :]
# Out:
#             invoiceno                 invoicedate stockcode  \
# customerid
# 17850          536365  2010-12-01 08:26:00.000000    85123A
# 17850          536373  2010-12-01 09:02:00.000000    85123A
# 17850          536375  2010-12-01 09:32:00.000000    85123A
# 17850          536396  2010-12-01 10:51:00.000000    85123A
# 17850          536406  2010-12-01 11:33:00.000000    85123A
# ...               ...                         ...       ...
# 17511          578125  2011-11-23 10:31:00.000000     23695
# 17511          581020  2011-12-07 10:12:00.000000     23695
# 17511          578125  2011-11-23 10:31:00.000000     23697
# 17511          578125  2011-11-23 10:31:00.000000     23694
# 17511          581020  2011-12-07 10:12:00.000000     23576
#
#                                    description  quantity  unitprice  revenue  \
# customerid
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        12       2.55    20.40
# ...                                        ...       ...        ...      ...
# 17511                     DOILY THANK YOU CARD        76       0.36    25.92
# 17511                     DOILY THANK YOU CARD        76       0.36    25.92
# 17511                  A PRETTY THANK YOU CARD        76       0.36    25.92
# 17511                        PAISLEY PARK CARD        76       0.36    25.92
# 17511             SNACK TRAY RED VINTAGE DOILY        52       1.65    79.20
#
#                    country    nullid  desciption_cambiada
# customerid
# 17850       United Kingdom  198017.0                    1
# 17850       United Kingdom       1.0                    1
# 17850       United Kingdom  198017.0                    1
# 17850       United Kingdom       5.0                    1
# 17850       United Kingdom       7.0                    1
# ...                    ...       ...                  ...
# 17511       United Kingdom  395405.0                    2
# 17511       United Kingdom  198017.0                    2
# 17511       United Kingdom  395443.0                    2
# 17511       United Kingdom  198017.0                    2
# 17511       United Kingdom  395963.0                    2
#
# [1260 rows x 10 columns]

# %%
# para varias columnas
df.loc[[17850, 17511], ["description", "quantity"]]
# Out:
#                                    description  quantity
# customerid
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        12
# ...                                        ...       ...
# 17511                     DOILY THANK YOU CARD        76
# 17511                     DOILY THANK YOU CARD        76
# 17511                  A PRETTY THANK YOU CARD        76
# 17511                        PAISLEY PARK CARD        76
# 17511             SNACK TRAY RED VINTAGE DOILY        52
#
# [1260 rows x 2 columns]

# %% [markdown]
# También podemos usar la sintaxis de:
#
# ```python
# [start: stop: step]
# ```

# %%
df.head(1)
# Out:
#             invoiceno                 invoicedate stockcode  \
# customerid
# 17850          536365  2010-12-01 08:26:00.000000    85123A
#
#                                    description  quantity  unitprice  revenue  \
# customerid
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
#
#                    country    nullid  desciption_cambiada
# customerid
# 17850       United Kingdom  198017.0                    1

# %%
# filtramos de dos en dos

df.loc[[17850, 17511], "invoiceno":"quantity":2]
# Out:
#             invoiceno stockcode  quantity
# customerid
# 17850          536365    85123A        10
# 17850          536373    85123A        10
# 17850          536375    85123A        10
# 17850          536396    85123A        10
# 17850          536406    85123A        12
# ...               ...       ...       ...
# 17511          578125     23695        76
# 17511          581020     23695        76
# 17511          578125     23697        76
# 17511          578125     23694        76
# 17511          581020     23576        52
#
# [1260 rows x 3 columns]

# %% [markdown]
# ## `iloc`
#
# Accedemos a través de los índices. Para usar este método tenemos que seguir la siguiente sintaxis:
#
# ```python
# [indice_fila, indice_columna]
# ```

# %% [markdown]
# Imaginemos que queremos acceder al primer índice de la columna "description".
#
# - `description`es la columna 4, como en el caso de las listas, empezamos a contar por 0, por lo tanto tiene el índice 3.

# %%
df.head(1)
# Out:
#             invoiceno                 invoicedate stockcode  \
# customerid
# 17850          536365  2010-12-01 08:26:00.000000    85123A
#
#                                    description  quantity  unitprice  revenue  \
# customerid
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
#
#                    country    nullid  desciption_cambiada
# customerid
# 17850       United Kingdom  198017.0                    1

# %%
# iloc para la primera fila, cuarta columna
df.iloc[0, 3]
# Out:
# 'CREAM HANGING HEART T-LIGHT HOLDER'

# %% [markdown]
# Si queremos que nos devuelva todas las columnas para la primera fila:

# %%
# iloc primera fila todas las columnas
df.iloc[0,:]
# Out:
# invoiceno                                          536365
# invoicedate                    2010-12-01 08:26:00.000000
# stockcode                                          85123A
# description            CREAM HANGING HEART T-LIGHT HOLDER
# quantity                                               10
# unitprice                                            2.55
# revenue                                              15.3
# country                                    United Kingdom
# nullid                                           198017.0
# desciption_cambiada                                     1
# Name: 17850, dtype: object

# %% [markdown]
# Y todas las filas para una columna dada?

# %%
# si nos fijamos en realidad es como extraer una columna
df.iloc[:,3]
# Out:
# customerid
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17850    CREAM HANGING HEART T-LIGHT HOLDER
# 17511    CREAM HANGING HEART T-LIGHT HOLDER
# 13408    CREAM HANGING HEART T-LIGHT HOLDER
#                         ...
# 13790             LETTER "W" BLING KEY RING
# 13790             LETTER "Z" BLING KEY RING
# 17914        PINK CRYSTAL SKULL PHONE CHARM
# 17914        PINK CRYSTAL SKULL PHONE CHARM
# 14796        PINK CRYSTAL SKULL PHONE CHARM
# Name: description, Length: 396034, dtype: object

# %%
# para ver los índices

df.index
# Out:
# Int64Index([17850, 17850, 17850, 17511, 13408, 17850, 15862, 17850, 16552,
#             14729,
#             ...
#             13790, 17870, 13790, 13790, 13790, 13790, 13790, 17914, 17914,
#             14796],
#            dtype='int64', name='customerid', length=396034)

# %% [markdown]
# ¿Y si queremos seleccionar varias filas y/o columnas?

# %%
df.iloc[1:9, 2:6]
# Out:
#            stockcode                         description  quantity  unitprice
# customerid
# 17850         85123A  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55
# 17850         85123A  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55
# 17511         85123A  CREAM HANGING HEART T-LIGHT HOLDER        68       2.55
# 13408         85123A  CREAM HANGING HEART T-LIGHT HOLDER        36       2.55
# 17850         85123A  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55
# 15862         85123A  CREAM HANGING HEART T-LIGHT HOLDER         8       2.95
# 17850         85123A  CREAM HANGING HEART T-LIGHT HOLDER        12       2.55
# 16552         85123A  CREAM HANGING HEART T-LIGHT HOLDER        10       2.95

# %% [markdown]
# Y si aplicamos la siguiente sintaxis?
#
# ```python
# [start:stop:step]
# ```

# %%
df.head(1)
# Out:
#             invoiceno                 invoicedate stockcode  \
# customerid
# 17850          536365  2010-12-01 08:26:00.000000    85123A
#
#                                    description  quantity  unitprice  revenue  \
# customerid
# 17850       CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
#
#                    country    nullid  desciption_cambiada
# customerid
# 17850       United Kingdom  198017.0                    1

# %%
# varias filas con steps
df.iloc[1:9, 0:10:2]
# Out:
#             invoiceno stockcode  quantity  revenue    nullid
# customerid
# 17850          536373    85123A        10     15.3       1.0
# 17850          536375    85123A        10     15.3  198017.0
# 17511          536390    85123A        68    163.2       3.0
# 13408          536394    85123A        36     81.6  198017.0
# 17850          536396    85123A        10     15.3       5.0
# 15862          536401    85123A         8     11.8  198017.0
# 17850          536406    85123A        12     20.4       7.0
# 16552          536502    85123A        10     17.7  198017.0

# %% [markdown]
# # Apply

# %% [markdown]
# Aplicar una función a un DataFrame de Pandas es una de las operaciones más comunes durante la manipulación de datos.
#
# La función `apply` de Pandas DataFrame es una de las mejores herramientas que tenemos en pandas para hacerlo. Toma una función como argumento y la aplica a lo largo de un eje del DataFrame.

# %%
# como es un csv enoooorme voy a coger solo 100 filas para los ejemplos de la clase:
dff = df.sample(100)

# %%
#recordemos como es nuestro dataframe

dff.head(2)
# Out:
#             invoiceno                 invoicedate stockcode  \
# customerid
# 16240          568065  2011-09-23 13:44:00.000000     23548
# 16447          561465  2011-07-27 12:45:00.000000     22079
#
#                            description  quantity  unitprice  revenue  \
# customerid
# 16240               WRAP MAGIC FOREST         29       0.42    10.50
# 16447       RIBBON REEL HEARTS DESIGN          9       1.65     8.25
#
#                    country    nullid  desciption_cambiada
# customerid
# 16240       United Kingdom  198017.0                    2
# 16447       United Kingdom  198017.0                    2

# %%
dff.dtypes
# Out:
# invoiceno                int64
# invoicedate             object
# stockcode               object
# description             object
# quantity                 int64
# unitprice              float64
# revenue                float64
# country                 object
# nullid                 float64
# desciption_cambiada      int64
# dtype: object

# %% [markdown]
# Si nos fijamos, tenemos una columna `invoicedata` que contiene muchos datos y que vamos a querer separar en varias columnas. Vamos a ello:

# %%
x = '2011-04-10 16:03:59.999999'

# %%
x.split(" ")
# Out:
# ['2011-04-10', '16:03:59.999999']

# %%
x.split(" ")[0]
# Out:
# '2011-04-10'

# %%
# lo primero que tenemos que hacer es una función que haga el split de los datos que queremos. 
def limpiar_fecha(x): 
    fecha_string = x.split(" ")[0]
    fecha_date = datetime.datetime.strptime(fecha_string, '%Y-%m-%d')
    return fecha_date

# %%
# usamos la función con el apply
dff["fecha"] = dff["invoicedate"].apply(limpiar_fecha)

# %%
limpiar_fecha(dff["invoicedate"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-6e6bced8244b> in <module>
# ----> 1 limpiar_fecha(dff["invoicedate"])
#
# <ipython-input-50-6cc70f35a46c> in limpiar_fecha(x)
#       1 # lo primero que tenemos que hacer es una función que haga el split de los datos que queremos.
#       2 def limpiar_fecha(x):
# ----> 3     fecha_string = x.split(" ")[0]
#       4     fecha_date = datetime.datetime.strptime(fecha_string, '%Y-%m-%d')
#       5     return fecha_date
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
# chequeamos los tipos de datos
dff.head(2)
# Out:
#             invoiceno                 invoicedate stockcode  \
# customerid
# 16240          568065  2011-09-23 13:44:00.000000     23548
# 16447          561465  2011-07-27 12:45:00.000000     22079
#
#                            description  quantity  unitprice  revenue  \
# customerid
# 16240               WRAP MAGIC FOREST         29       0.42    10.50
# 16447       RIBBON REEL HEARTS DESIGN          9       1.65     8.25
#
#                    country    nullid  desciption_cambiada      fecha
# customerid
# 16240       United Kingdom  198017.0                    2 2011-09-23
# 16447       United Kingdom  198017.0                    2 2011-07-27

# %%
# que datos tenemos ahora?
dff.dtypes
# Out:
# invoiceno                       int64
# invoicedate                    object
# stockcode                      object
# description                    object
# quantity                        int64
# unitprice                     float64
# revenue                       float64
# country                        object
# nullid                        float64
# desciption_cambiada             int64
# fecha                  datetime64[ns]
# dtype: object

# %% [markdown]
# 🌊📝 **EJERCICIO** Es vuestro turno, ahora tenéis que crear una columna únicamente con la hora.

# %% [markdown]
# Imaginemos que queremos sacar las coordenadas como latitud y longitud de nuestros paises. También lo podemos hacer usando la librería `geopy`.
#
# [Aquí](https://pypi.org/project/geopy/) la documentación a la página oficial.

# %%
# lo primero que tenemos que hacer es importar la librería
from geopy.geocoders import Nominatim

# %%
y = "United Kingdom"

geolocator = Nominatim(user_agent = "ana")

location = geolocator.geocode(y)

# %%
location
# Out:
# Location(United Kingdom, (54.7023545, -3.2765753, 0.0))

# %%
location.latitude
# Out:
# 54.7023545

# %%
location.longitude
# Out:
# -3.2765753

# %%
location = geolocator.reverse("52.509669, 13.376294")

# %%
location
# Out:
# Location(Steinecke, Potsdamer Platz, Tiergarten, Mitte, Berlin, 10785, Deutschland, (52.5098134, 13.37631790998454, 0.0))

# %%
def extraer_coordenadas(x):
    try:
        geolocator = Nominatim(user_agent = "ana")
        location = geolocator.geocode(x)
        return location.latitude, location.longitude
    except:
        return "no hay datos"

# %%
# ejecutamos la funcion

dff["coordenadas"] = dff["country"].apply(extraer_coordenadas)

# %%
dff.head(1)
# Out:
#             invoiceno                 invoicedate stockcode  \
# customerid
# 16240          568065  2011-09-23 13:44:00.000000     23548
#
#                    description  quantity  unitprice  revenue         country  \
# customerid
# 16240       WRAP MAGIC FOREST         29       0.42     10.5  United Kingdom
#
#               nullid  desciption_cambiada      fecha               coordenadas
# customerid
# 16240       198017.0                    2 2011-09-23  (54.7023545, -3.2765753)

# %%
dff.coordenadas.unique()
# Out:
# array([(54.7023545, -3.2765753), (39.3260685, -4.8379791),
#        (51.0834196, 10.4234469), (55.670249, 10.3333283),
#        (50.6402809, 4.6667145), (46.603354, 1.8883335),
#        (52.865196, -7.9794599), (33.96579515, -120.09189711105296)],
#       dtype=object)

# %% [markdown]
# Si nos fijamos nos crea una columna donde el valor es una tupla. Oh oh... 😔
#
# Sigamos haciendo funciones y apply para poner nuestro dataframe limpito

# %%
# mostramos resultados

# %% [markdown]
# **TAMBIÉN PODEMOS HACER UN APPLY A MULTIPLES COLUMNAS**
#
# Imaginemos que queremos saber el dinero gastado por un cliente en sus compras.
# Podemos hacernos una función a la que le pasemos dos columnas y nos devuelva una columna nueva

# %%
#creamos la duncion precio total
def precio_total(x, y):
    return x * y

# %%
# hacemos el apply con el lambda
dff["precio_total"] = dff.apply(lambda chorizo: precio_total(chorizo["quantity"], chorizo["unitprice"] ), axis = 1)

# %%
dff["precio_total2"] = dff.apply(lambda data: data["unitprice"] * data["quantity"] , axis = 1)

# %%
# vemos los resultados
dff.head(1)
# Out:
#             invoiceno                 invoicedate stockcode  \
# customerid
# 16240          568065  2011-09-23 13:44:00.000000     23548
#
#                    description  quantity  unitprice  revenue         country  \
# customerid
# 16240       WRAP MAGIC FOREST         29       0.42     10.5  United Kingdom
#
#               nullid  desciption_cambiada      fecha  \
# customerid
# 16240       198017.0                    2 2011-09-23
#
#                          coordenadas  precio_total  precio_total2
# customerid
# 16240       (54.7023545, -3.2765753)         12.18          12.18

# %% [markdown]
# # Groupby

# %% [markdown]
# En el análisis exploratorio de datos, a menudo nos gustaría analizar los datos por algunas categorías.
#
# En Pandas, tenemos el método `groupby()` que nos permite dividir los datos en grupos separados para realizar cálculos para un mejor análisis.

# %%
# recordamos el dataframe
dff.head(2)
# Out:
#             invoiceno                 invoicedate stockcode  \
# customerid
# 16240          568065  2011-09-23 13:44:00.000000     23548
# 16447          561465  2011-07-27 12:45:00.000000     22079
#
#                            description  quantity  unitprice  revenue  \
# customerid
# 16240               WRAP MAGIC FOREST         29       0.42    10.50
# 16447       RIBBON REEL HEARTS DESIGN          9       1.65     8.25
#
#                    country    nullid  desciption_cambiada      fecha  \
# customerid
# 16240       United Kingdom  198017.0                    2 2011-09-23
# 16447       United Kingdom  198017.0                    2 2011-07-27
#
#                          coordenadas  precio_total  precio_total2
# customerid
# 16240       (54.7023545, -3.2765753)         12.18          12.18
# 16447       (54.7023545, -3.2765753)         14.85          14.85

# %%
# lo primero que vamos a hacer es resetear el índice
dff.reset_index(inplace = True)

# %%
dff.head(2)
# Out:
#    customerid  invoiceno                 invoicedate stockcode  \
# 0       16240     568065  2011-09-23 13:44:00.000000     23548
# 1       16447     561465  2011-07-27 12:45:00.000000     22079
#
#                   description  quantity  unitprice  revenue         country  \
# 0          WRAP MAGIC FOREST         29       0.42    10.50  United Kingdom
# 1  RIBBON REEL HEARTS DESIGN          9       1.65     8.25  United Kingdom
#
#      nullid  desciption_cambiada      fecha               coordenadas  \
# 0  198017.0                    2 2011-09-23  (54.7023545, -3.2765753)
# 1  198017.0                    2 2011-07-27  (54.7023545, -3.2765753)
#
#    precio_total  precio_total2
# 0         12.18          12.18
# 1         14.85          14.85

# %%
# imaginemos que queremos saber la media de compras que hizo un cliente en fncion del producto
dff.groupby(['customerid', "description"]).mean()
# Out:
#                                                 invoiceno  quantity  \
# customerid description
# 12395      ALARM CLOCK BAKELIKE GREEN              569496         8
# 12412      CHILDRENS CUTLERY SPACEBOY              557889         8
# 12476      GUMBALL MAGAZINE RACK                   578472         6
# 12534      BLUE STRIPE CERAMIC DRAWER KNOB         561911        16
# 12540      PACK OF 12 WOODLAND TISSUES             555095        28
# 12562      JUMBO BAG DOILEY PATTERNS               576941        14
# 12569      SET/2 RED RETROSPOT TEA TOWELS          570784        16
# 12614      DOORMAT TOPIARY                         545718         6
# 12621      CHARLOTTE BAG APPLES DESIGN             551258        24
#            FELTCRAFT CUSHION RABBIT                551258        12
# 12714      6 GIFT TAGS 50'S CHRISTMAS              564372        16
# 12748      ILLUSTRATED CAT BOWL                    547809         5
# 12988      PLEASE ONE PERSON METAL SIGN            544463         5
# 13004      CREAM HANGING HEART T-LIGHT HOLDER      548749        10
# 13021      BOX OF 6 CHRISTMAS CAKE DECORATIONS     573907        16
# 13066      BATHROOM METAL SIGN                     576554        16
# 13313      LUNCH BAG PINK POLKADOT                 560915        14
# 13344      GEORGIAN TRINKET BOX                    569244         6
# 13521      ANTIQUE ALL GLASS CANDLESTICK           579472         6
# 13742      SWEETHEART WIRE WALL TIDY               555554         8
# 13850      GIFT BAG LARGE VINTAGE CHRISTMAS        562101        16
# 13949      3 HOOK HANGER MAGIC GARDEN              565725        16
# 14096      SET OF 36 DOILIES PANTRY DESIGN         575607         5
#            SET OF 4 PANTRY JELLY MOULDS            569246         5
# 14334      6 RIBBONS RUSTIC CHARM                  546182        16
# 14415      JUMBO BAG PEARS                         573264         6
# 14482      HAND WARMER SCOTTY DOG DESIGN           575368         5
# 14562      3 DRAWER ANTIQUE WHITE WOOD CABINET     550994         5
# 14606      CANDLEHOLDER PINK HANGING HEART         554491         5
# 14710      ASSORTED COLOUR BIRD ORNAMENT           573364        10
# 14748      WRAP MAGIC FOREST                       562616        29
# 14776      SET OF 60 I LOVE LONDON CAKE CASES      557220        28
# 14911      SET 3 PAPER VINTAGE CHICK PAPER EGG     548664        10
# 14936      SET OF 6 NATIVITY MAGNETS               569558        28
# 15023      WRAP PINK FAIRY CAKES                   541489        29
# 15039       TRELLIS COAT RACK                      575046         6
#            RED RETROSPOT BOWL                      540023         7
# 15046      SINGLE WIRE HOOK IVORY HEART            562378        16
# 15152      ENAMEL FLOWER JUG CREAM                 562256         7
# 15277      TRADITIONAL PICK UP STICKS GAME         572327        16
# 15382      POPCORN HOLDER                          578702        52
# 15427      SET/4 BADGES BEETLES                    574714         5
# 15514      GLOW IN DARK DOLPHINS                   578667         7
# 15531      PAPER CHAIN KIT 50'S CHRISTMAS          580133        18
# 15544      LUNCH BAG ALPHABET DESIGN               559814        14
# 15570      STAR WOODEN CHRISTMAS DECORATION        539450        10
# 15601      CARD CIRCUS PARADE                      544294        16
# 15639      BANQUET BIRTHDAY  CARD                  561632        28
# 15676      SET OF 3 NOTEBOOKS IN PARCEL            574532        16
# 15719      3 PIECE SPACEBOY COOKIE CUTTER SET      574863         5
# 15752      HEART WOODEN CHRISTMAS DECORATION       565915        14
# 15780      CREAM WALL PLANTER HEART SHAPED         556190         6
# 15808      ROSES REGENCY TEACUP AND SAUCER         538660         8
# 15858      SMALL GLASS HEART TRINKET POT           578479        12
# 15952      FRENCH ENAMEL POT W LID                 558768         5
# 16007      JUMBO BAG OWLS                          556474         5
# 16019      REGENCY CAKESTAND 3 TIER                540409        20
# 16033      SET OF 6 SPICE TINS PANTRY DESIGN       569523         6
# 16070      VINTAGE CHRISTMAS BUNTING               574921         9
# 16173      JUMBO BAG DOILEY PATTERNS               578366        14
# 16240      WRAP MAGIC FOREST                       568065        29
# 16253      VINTAGE SEASIDE JIGSAW PUZZLES          548160         8
# 16327      WHITE METAL LANTERN                     546538         8
# 16447      RIBBON REEL HEARTS DESIGN               561465         9
# 16494      DECORATION  PINK CHICK MAGIC GARDEN     544160        11
# 16539      DOORMAT KEEP CALM AND COME IN           581004        14
# 16701      MAGNETS PACK OF 4 CHILDHOOD MEMORY      547861        16
# 16712      ROUND SNACK BOXES SET OF 4 SKULLS       548198         5
# 16713      LUNCH BAG ALPHABET DESIGN               577723         7
# 16722      WRAP RED APPLES                         550995        29
# 16923      LARGE CERAMIC TOP STORAGE JAR           565151         5
# 16928      GREEN REGENCY TEACUP AND SAUCER         552270         5
# 17034      RED METAL BOX TOP SECRET                567523         6
# 17069      NATURAL SLATE HEART CHALKBOARD          549576        10
# 17079      BUNTING , SPOTTY                        567888        16
# 17086      LUNCH BAG CARS BLUE                     574091        14
# 17092      SET OF 3 WOODEN TREE DECORATIONS        566560         9
# 17107      SCOTTIE DOG HOT WATER BOTTLE            568193         5
# 17119      SMALL SILVER FLOWER CANDLE POT          570555        10
# 17358      FANCY FONT BIRTHDAY CARD,               539471        16
# 17403      PLASTERS IN TIN VINTAGE PAISLEY         574290         5
# 17405      PARISIENNE KEY CABINET                  559804         6
# 17406      FENG SHUI PILLAR CANDLE                 540647         9
# 17419      SET OF 3 CAKE TINS PANTRY DESIGN        541522         7
# 17555      JUMBO BAG STRAWBERRY                    540520         6
# 17593      6 RIBBONS EMPIRE                        580759        28
# 17612      MAGNETS PACK OF 4 RETRO PHOTO           563755        16
# 17634      SET OF 3 CAKE TINS PANTRY DESIGN        540288         7
# 17735      REGENCY CAKESTAND 3 TIER                560571         5
# 17768      PLASTERS IN TIN SPACEBOY                574709        28
# 17841      CHRISTMAS TREE HANGING SILVER           573496         6
#            JUMBO BAG SCANDINAVIAN BLUE PAISLEY     570818         5
#            TREASURE TIN GYMKHANA DESIGN            562779         5
# 17873      WASHROOM METAL SIGN                     545558        28
# 18005      VINTAGE SNAP CARDS                      580848         5
# 18022      RED RETROSPOT CUP                       574481         6
# 18055      WOODEN PICTURE FRAME WHITE FINISH       562205        10
# 18109      FINE WICKER HEART                       554995         6
# 18118      MOODY GIRL DOOR HANGER                  579301         6
#            SET/10 RED POLKADOT PARTY CANDLES       551739         5
#
#                                                 unitprice  revenue    nullid  \
# customerid description
# 12395      ALARM CLOCK BAKELIKE GREEN                3.75    15.00   12889.0
# 12412      CHILDRENS CUTLERY SPACEBOY                4.15    16.60  198017.0
# 12476      GUMBALL MAGAZINE RACK                     7.65    15.30  176637.0
# 12534      BLUE STRIPE CERAMIC DRAWER KNOB           1.25    15.00  198017.0
# 12540      PACK OF 12 WOODLAND TISSUES               0.29     6.96  169981.0
# 12562      JUMBO BAG DOILEY PATTERNS                 2.08    20.80  198017.0
# 12569      SET/2 RED RETROSPOT TEA TOWELS            3.25    39.00  198017.0
# 12614      DOORMAT TOPIARY                           7.95    15.90  198017.0
# 12621      CHARLOTTE BAG APPLES DESIGN               0.85    17.00  198017.0
#            FELTCRAFT CUSHION RABBIT                  3.75    30.00  198017.0
# 12714      6 GIFT TAGS 50'S CHRISTMAS                0.83     9.96  198017.0
# 12748      ILLUSTRATED CAT BOWL                      2.55     2.55  198017.0
# 12988      PLEASE ONE PERSON METAL SIGN              2.10     2.10  189093.0
# 13004      CREAM HANGING HEART T-LIGHT HOLDER        2.95    17.70     683.0
# 13021      BOX OF 6 CHRISTMAS CAKE DECORATIONS       3.75    45.00  391241.0
# 13066      BATHROOM METAL SIGN                       0.55     6.60  198017.0
# 13313      LUNCH BAG PINK POLKADOT                   1.65    16.50   85731.0
# 13344      GEORGIAN TRINKET BOX                     12.50    25.00  198017.0
# 13521      ANTIQUE ALL GLASS CANDLESTICK             2.10     4.20  198017.0
# 13742      SWEETHEART WIRE WALL TIDY                 9.95    39.80  131641.0
# 13850      GIFT BAG LARGE VINTAGE CHRISTMAS          1.25    15.00  198017.0
# 13949      3 HOOK HANGER MAGIC GARDEN                1.95    23.40  161149.0
# 14096      SET OF 36 DOILIES PANTRY DESIGN           2.92     2.92  353915.0
#            SET OF 4 PANTRY JELLY MOULDS              2.46     2.46  313389.0
# 14334      6 RIBBONS RUSTIC CHARM                    1.65    19.80  112153.0
# 14415      JUMBO BAG PEARS                           2.08     4.16  198017.0
# 14482      HAND WARMER SCOTTY DOG DESIGN             2.10     2.10  198017.0
# 14562      3 DRAWER ANTIQUE WHITE WOOD CABINET       8.95     8.95   20717.0
# 14606      CANDLEHOLDER PINK HANGING HEART           2.95     2.95   82771.0
# 14710      ASSORTED COLOUR BIRD ORNAMENT             1.69    10.14  198017.0
# 14748      WRAP MAGIC FOREST                         0.42    10.50  373681.0
# 14776      SET OF 60 I LOVE LONDON CAKE CASES        0.55    13.20  352711.0
# 14911      SET 3 PAPER VINTAGE CHICK PAPER EGG       2.95    17.70  198017.0
# 14936      SET OF 6 NATIVITY MAGNETS                 2.08    49.92  198017.0
# 15023      WRAP PINK FAIRY CAKES                     0.42    10.50  229903.0
# 15039       TRELLIS COAT RACK                        4.95     9.90  198017.0
#            RED RETROSPOT BOWL                        1.25     3.75  211585.0
# 15046      SINGLE WIRE HOOK IVORY HEART              1.45    17.40  331775.0
# 15152      ENAMEL FLOWER JUG CREAM                   5.95    17.85   49995.0
# 15277      TRADITIONAL PICK UP STICKS GAME           1.25    15.00  198017.0
# 15382      POPCORN HOLDER                            0.85    40.80  198017.0
# 15427      SET/4 BADGES BEETLES                      1.25     1.25  198017.0
# 15514      GLOW IN DARK DOLPHINS                     0.21     0.63  303945.0
# 15531      PAPER CHAIN KIT 50'S CHRISTMAS            2.95    41.30  198017.0
# 15544      LUNCH BAG ALPHABET DESIGN                 1.65    16.50  326197.0
# 15570      STAR WOODEN CHRISTMAS DECORATION          0.85     5.10  138053.0
# 15601      CARD CIRCUS PARADE                        0.42     5.04  101841.0
# 15639      BANQUET BIRTHDAY  CARD                    0.42    10.08  281373.0
# 15676      SET OF 3 NOTEBOOKS IN PARCEL              1.65    19.80  198017.0
# 15719      3 PIECE SPACEBOY COOKIE CUTTER SET        2.10     2.10   90135.0
# 15752      HEART WOODEN CHRISTMAS DECORATION         0.85     8.50  198017.0
# 15780      CREAM WALL PLANTER HEART SHAPED           5.95    11.90  219763.0
# 15808      ROSES REGENCY TEACUP AND SAUCER           2.95    11.80  198017.0
# 15858      SMALL GLASS HEART TRINKET POT             2.10    16.80  198017.0
# 15952      FRENCH ENAMEL POT W LID                   2.95     2.95  198017.0
# 16007      JUMBO BAG OWLS                            2.08     2.08  107489.0
# 16019      REGENCY CAKESTAND 3 TIER                 10.95   175.20  198017.0
# 16033      SET OF 6 SPICE TINS PANTRY DESIGN         3.95     7.90  198017.0
# 16070      VINTAGE CHRISTMAS BUNTING                 4.95    24.75  370709.0
# 16173      JUMBO BAG DOILEY PATTERNS                 2.08    20.80  198017.0
# 16240      WRAP MAGIC FOREST                         0.42    10.50  198017.0
# 16253      VINTAGE SEASIDE JIGSAW PUZZLES            3.75    15.00  198017.0
# 16327      WHITE METAL LANTERN                       3.75    15.00    2107.0
# 16447      RIBBON REEL HEARTS DESIGN                 1.65     8.25  198017.0
# 16494      DECORATION  PINK CHICK MAGIC GARDEN       0.85     5.95  307293.0
# 16539      DOORMAT KEEP CALM AND COME IN             7.08    70.80  333129.0
# 16701      MAGNETS PACK OF 4 CHILDHOOD MEMORY        1.25    15.00  198017.0
# 16712      ROUND SNACK BOXES SET OF 4 SKULLS         2.95     2.95  198017.0
# 16713      LUNCH BAG ALPHABET DESIGN                 1.65     4.95  326539.0
# 16722      WRAP RED APPLES                           0.42    10.50  198017.0
# 16923      LARGE CERAMIC TOP STORAGE JAR             1.65     1.65  346953.0
# 16928      GREEN REGENCY TEACUP AND SAUCER           2.95     2.95  157337.0
# 17034      RED METAL BOX TOP SECRET                  8.25    16.50  343695.0
# 17069      NATURAL SLATE HEART CHALKBOARD            2.95    17.70  198017.0
# 17079      BUNTING , SPOTTY                          4.95    59.40  198017.0
# 17086      LUNCH BAG CARS BLUE                       1.65    16.50   93593.0
# 17092      SET OF 3 WOODEN TREE DECORATIONS          1.25     6.25  359751.0
# 17107      SCOTTIE DOG HOT WATER BOTTLE              4.95     4.95  198017.0
# 17119      SMALL SILVER FLOWER CANDLE POT            2.95    17.70  271219.0
# 17358      FANCY FONT BIRTHDAY CARD,                 0.42     5.04   66035.0
# 17403      PLASTERS IN TIN VINTAGE PAISLEY           1.65     1.65  125951.0
# 17405      PARISIENNE KEY CABINET                    5.75    11.50  343905.0
# 17406      FENG SHUI PILLAR CANDLE                   0.19     0.95  198017.0
# 17419      SET OF 3 CAKE TINS PANTRY DESIGN          4.95    14.85  198017.0
# 17555      JUMBO BAG STRAWBERRY                      1.95     3.90  108165.0
# 17593      6 RIBBONS EMPIRE                          0.39     9.36  250013.0
# 17612      MAGNETS PACK OF 4 RETRO PHOTO             0.39     4.68  257935.0
# 17634      SET OF 3 CAKE TINS PANTRY DESIGN          4.95    14.85  295255.0
# 17735      REGENCY CAKESTAND 3 TIER                 12.75    12.75  143133.0
# 17768      PLASTERS IN TIN SPACEBOY                  1.65    39.60  126521.0
# 17841      CHRISTMAS TREE HANGING SILVER             0.83     1.66  198017.0
#            JUMBO BAG SCANDINAVIAN BLUE PAISLEY       2.08     2.08  182267.0
#            TREASURE TIN GYMKHANA DESIGN              2.08     2.08  198017.0
# 17873      WASHROOM METAL SIGN                       1.45    34.80  198017.0
# 18005      VINTAGE SNAP CARDS                        0.85     0.85  120763.0
# 18022      RED RETROSPOT CUP                         0.85     1.70  198179.0
# 18055      WOODEN PICTURE FRAME WHITE FINISH         2.55    15.30  198017.0
# 18109      FINE WICKER HEART                         1.25     2.50  193729.0
# 18118      MOODY GIRL DOOR HANGER                    0.39     0.78  217425.0
#            SET/10 RED POLKADOT PARTY CANDLES         1.25     1.25  135539.0
#
#                                                 desciption_cambiada  \
# customerid description
# 12395      ALARM CLOCK BAKELIKE GREEN                             2
# 12412      CHILDRENS CUTLERY SPACEBOY                             2
# 12476      GUMBALL MAGAZINE RACK                                  2
# 12534      BLUE STRIPE CERAMIC DRAWER KNOB                        2
# 12540      PACK OF 12 WOODLAND TISSUES                            2
# 12562      JUMBO BAG DOILEY PATTERNS                              2
# 12569      SET/2 RED RETROSPOT TEA TOWELS                         2
# 12614      DOORMAT TOPIARY                                        2
# 12621      CHARLOTTE BAG APPLES DESIGN                            2
#            FELTCRAFT CUSHION RABBIT                               2
# 12714      6 GIFT TAGS 50'S CHRISTMAS                             2
# 12748      ILLUSTRATED CAT BOWL                                   2
# 12988      PLEASE ONE PERSON METAL SIGN                           2
# 13004      CREAM HANGING HEART T-LIGHT HOLDER                     1
# 13021      BOX OF 6 CHRISTMAS CAKE DECORATIONS                    2
# 13066      BATHROOM METAL SIGN                                    2
# 13313      LUNCH BAG PINK POLKADOT                                2
# 13344      GEORGIAN TRINKET BOX                                   2
# 13521      ANTIQUE ALL GLASS CANDLESTICK                          2
# 13742      SWEETHEART WIRE WALL TIDY                              2
# 13850      GIFT BAG LARGE VINTAGE CHRISTMAS                       2
# 13949      3 HOOK HANGER MAGIC GARDEN                             2
# 14096      SET OF 36 DOILIES PANTRY DESIGN                        2
#            SET OF 4 PANTRY JELLY MOULDS                           2
# 14334      6 RIBBONS RUSTIC CHARM                                 2
# 14415      JUMBO BAG PEARS                                        2
# 14482      HAND WARMER SCOTTY DOG DESIGN                          2
# 14562      3 DRAWER ANTIQUE WHITE WOOD CABINET                    2
# 14606      CANDLEHOLDER PINK HANGING HEART                        2
# 14710      ASSORTED COLOUR BIRD ORNAMENT                          2
# 14748      WRAP MAGIC FOREST                                      2
# 14776      SET OF 60 I LOVE LONDON CAKE CASES                     2
# 14911      SET 3 PAPER VINTAGE CHICK PAPER EGG                    2
# 14936      SET OF 6 NATIVITY MAGNETS                              2
# 15023      WRAP PINK FAIRY CAKES                                  2
# 15039       TRELLIS COAT RACK                                     2
#            RED RETROSPOT BOWL                                     2
# 15046      SINGLE WIRE HOOK IVORY HEART                           2
# 15152      ENAMEL FLOWER JUG CREAM                                2
# 15277      TRADITIONAL PICK UP STICKS GAME                        2
# 15382      POPCORN HOLDER                                         2
# 15427      SET/4 BADGES BEETLES                                   2
# 15514      GLOW IN DARK DOLPHINS                                  2
# 15531      PAPER CHAIN KIT 50'S CHRISTMAS                         2
# 15544      LUNCH BAG ALPHABET DESIGN                              2
# 15570      STAR WOODEN CHRISTMAS DECORATION                       2
# 15601      CARD CIRCUS PARADE                                     2
# 15639      BANQUET BIRTHDAY  CARD                                 2
# 15676      SET OF 3 NOTEBOOKS IN PARCEL                           2
# 15719      3 PIECE SPACEBOY COOKIE CUTTER SET                     2
# 15752      HEART WOODEN CHRISTMAS DECORATION                      2
# 15780      CREAM WALL PLANTER HEART SHAPED                        2
# 15808      ROSES REGENCY TEACUP AND SAUCER                        2
# 15858      SMALL GLASS HEART TRINKET POT                          2
# 15952      FRENCH ENAMEL POT W LID                                2
# 16007      JUMBO BAG OWLS                                         2
# 16019      REGENCY CAKESTAND 3 TIER                               2
# 16033      SET OF 6 SPICE TINS PANTRY DESIGN                      2
# 16070      VINTAGE CHRISTMAS BUNTING                              2
# 16173      JUMBO BAG DOILEY PATTERNS                              2
# 16240      WRAP MAGIC FOREST                                      2
# 16253      VINTAGE SEASIDE JIGSAW PUZZLES                         2
# 16327      WHITE METAL LANTERN                                    2
# 16447      RIBBON REEL HEARTS DESIGN                              2
# 16494      DECORATION  PINK CHICK MAGIC GARDEN                    2
# 16539      DOORMAT KEEP CALM AND COME IN                          2
# 16701      MAGNETS PACK OF 4 CHILDHOOD MEMORY                     2
# 16712      ROUND SNACK BOXES SET OF 4 SKULLS                      2
# 16713      LUNCH BAG ALPHABET DESIGN                              2
# 16722      WRAP RED APPLES                                        2
# 16923      LARGE CERAMIC TOP STORAGE JAR                          2
# 16928      GREEN REGENCY TEACUP AND SAUCER                        2
# 17034      RED METAL BOX TOP SECRET                               2
# 17069      NATURAL SLATE HEART CHALKBOARD                         2
# 17079      BUNTING , SPOTTY                                       2
# 17086      LUNCH BAG CARS BLUE                                    2
# 17092      SET OF 3 WOODEN TREE DECORATIONS                       2
# 17107      SCOTTIE DOG HOT WATER BOTTLE                           2
# 17119      SMALL SILVER FLOWER CANDLE POT                         2
# 17358      FANCY FONT BIRTHDAY CARD,                              2
# 17403      PLASTERS IN TIN VINTAGE PAISLEY                        2
# 17405      PARISIENNE KEY CABINET                                 2
# 17406      FENG SHUI PILLAR CANDLE                                2
# 17419      SET OF 3 CAKE TINS PANTRY DESIGN                       2
# 17555      JUMBO BAG STRAWBERRY                                   2
# 17593      6 RIBBONS EMPIRE                                       2
# 17612      MAGNETS PACK OF 4 RETRO PHOTO                          2
# 17634      SET OF 3 CAKE TINS PANTRY DESIGN                       2
# 17735      REGENCY CAKESTAND 3 TIER                               2
# 17768      PLASTERS IN TIN SPACEBOY                               2
# 17841      CHRISTMAS TREE HANGING SILVER                          2
#            JUMBO BAG SCANDINAVIAN BLUE PAISLEY                    2
#            TREASURE TIN GYMKHANA DESIGN                           2
# 17873      WASHROOM METAL SIGN                                    2
# 18005      VINTAGE SNAP CARDS                                     2
# 18022      RED RETROSPOT CUP                                      2
# 18055      WOODEN PICTURE FRAME WHITE FINISH                      2
# 18109      FINE WICKER HEART                                      2
# 18118      MOODY GIRL DOOR HANGER                                 2
#            SET/10 RED POLKADOT PARTY CANDLES                      2
#
#                                                 precio_total  precio_total2
# customerid description
# 12395      ALARM CLOCK BAKELIKE GREEN                  30.00          30.00
# 12412      CHILDRENS CUTLERY SPACEBOY                  33.20          33.20
# 12476      GUMBALL MAGAZINE RACK                       45.90          45.90
# 12534      BLUE STRIPE CERAMIC DRAWER KNOB             20.00          20.00
# 12540      PACK OF 12 WOODLAND TISSUES                  8.12           8.12
# 12562      JUMBO BAG DOILEY PATTERNS                   29.12          29.12
# 12569      SET/2 RED RETROSPOT TEA TOWELS              52.00          52.00
# 12614      DOORMAT TOPIARY                             47.70          47.70
# 12621      CHARLOTTE BAG APPLES DESIGN                 20.40          20.40
#            FELTCRAFT CUSHION RABBIT                    45.00          45.00
# 12714      6 GIFT TAGS 50'S CHRISTMAS                  13.28          13.28
# 12748      ILLUSTRATED CAT BOWL                        12.75          12.75
# 12988      PLEASE ONE PERSON METAL SIGN                10.50          10.50
# 13004      CREAM HANGING HEART T-LIGHT HOLDER          29.50          29.50
# 13021      BOX OF 6 CHRISTMAS CAKE DECORATIONS         60.00          60.00
# 13066      BATHROOM METAL SIGN                          8.80           8.80
# 13313      LUNCH BAG PINK POLKADOT                     23.10          23.10
# 13344      GEORGIAN TRINKET BOX                        75.00          75.00
# 13521      ANTIQUE ALL GLASS CANDLESTICK               12.60          12.60
# 13742      SWEETHEART WIRE WALL TIDY                   79.60          79.60
# 13850      GIFT BAG LARGE VINTAGE CHRISTMAS            20.00          20.00
# 13949      3 HOOK HANGER MAGIC GARDEN                  31.20          31.20
# 14096      SET OF 36 DOILIES PANTRY DESIGN             14.60          14.60
#            SET OF 4 PANTRY JELLY MOULDS                12.30          12.30
# 14334      6 RIBBONS RUSTIC CHARM                      26.40          26.40
# 14415      JUMBO BAG PEARS                             12.48          12.48
# 14482      HAND WARMER SCOTTY DOG DESIGN               10.50          10.50
# 14562      3 DRAWER ANTIQUE WHITE WOOD CABINET         44.75          44.75
# 14606      CANDLEHOLDER PINK HANGING HEART             14.75          14.75
# 14710      ASSORTED COLOUR BIRD ORNAMENT               16.90          16.90
# 14748      WRAP MAGIC FOREST                           12.18          12.18
# 14776      SET OF 60 I LOVE LONDON CAKE CASES          15.40          15.40
# 14911      SET 3 PAPER VINTAGE CHICK PAPER EGG         29.50          29.50
# 14936      SET OF 6 NATIVITY MAGNETS                   58.24          58.24
# 15023      WRAP PINK FAIRY CAKES                       12.18          12.18
# 15039       TRELLIS COAT RACK                          29.70          29.70
#            RED RETROSPOT BOWL                           8.75           8.75
# 15046      SINGLE WIRE HOOK IVORY HEART                23.20          23.20
# 15152      ENAMEL FLOWER JUG CREAM                     41.65          41.65
# 15277      TRADITIONAL PICK UP STICKS GAME             20.00          20.00
# 15382      POPCORN HOLDER                              44.20          44.20
# 15427      SET/4 BADGES BEETLES                         6.25           6.25
# 15514      GLOW IN DARK DOLPHINS                        1.47           1.47
# 15531      PAPER CHAIN KIT 50'S CHRISTMAS              53.10          53.10
# 15544      LUNCH BAG ALPHABET DESIGN                   23.10          23.10
# 15570      STAR WOODEN CHRISTMAS DECORATION             8.50           8.50
# 15601      CARD CIRCUS PARADE                           6.72           6.72
# 15639      BANQUET BIRTHDAY  CARD                      11.76          11.76
# 15676      SET OF 3 NOTEBOOKS IN PARCEL                26.40          26.40
# 15719      3 PIECE SPACEBOY COOKIE CUTTER SET          10.50          10.50
# 15752      HEART WOODEN CHRISTMAS DECORATION           11.90          11.90
# 15780      CREAM WALL PLANTER HEART SHAPED             35.70          35.70
# 15808      ROSES REGENCY TEACUP AND SAUCER             23.60          23.60
# 15858      SMALL GLASS HEART TRINKET POT               25.20          25.20
# 15952      FRENCH ENAMEL POT W LID                     14.75          14.75
# 16007      JUMBO BAG OWLS                              10.40          10.40
# 16019      REGENCY CAKESTAND 3 TIER                   219.00         219.00
# 16033      SET OF 6 SPICE TINS PANTRY DESIGN           23.70          23.70
# 16070      VINTAGE CHRISTMAS BUNTING                   44.55          44.55
# 16173      JUMBO BAG DOILEY PATTERNS                   29.12          29.12
# 16240      WRAP MAGIC FOREST                           12.18          12.18
# 16253      VINTAGE SEASIDE JIGSAW PUZZLES              30.00          30.00
# 16327      WHITE METAL LANTERN                         30.00          30.00
# 16447      RIBBON REEL HEARTS DESIGN                   14.85          14.85
# 16494      DECORATION  PINK CHICK MAGIC GARDEN          9.35           9.35
# 16539      DOORMAT KEEP CALM AND COME IN               99.12          99.12
# 16701      MAGNETS PACK OF 4 CHILDHOOD MEMORY          20.00          20.00
# 16712      ROUND SNACK BOXES SET OF 4 SKULLS           14.75          14.75
# 16713      LUNCH BAG ALPHABET DESIGN                   11.55          11.55
# 16722      WRAP RED APPLES                             12.18          12.18
# 16923      LARGE CERAMIC TOP STORAGE JAR                8.25           8.25
# 16928      GREEN REGENCY TEACUP AND SAUCER             14.75          14.75
# 17034      RED METAL BOX TOP SECRET                    49.50          49.50
# 17069      NATURAL SLATE HEART CHALKBOARD              29.50          29.50
# 17079      BUNTING , SPOTTY                            79.20          79.20
# 17086      LUNCH BAG CARS BLUE                         23.10          23.10
# 17092      SET OF 3 WOODEN TREE DECORATIONS            11.25          11.25
# 17107      SCOTTIE DOG HOT WATER BOTTLE                24.75          24.75
# 17119      SMALL SILVER FLOWER CANDLE POT              29.50          29.50
# 17358      FANCY FONT BIRTHDAY CARD,                    6.72           6.72
# 17403      PLASTERS IN TIN VINTAGE PAISLEY              8.25           8.25
# 17405      PARISIENNE KEY CABINET                      34.50          34.50
# 17406      FENG SHUI PILLAR CANDLE                      1.71           1.71
# 17419      SET OF 3 CAKE TINS PANTRY DESIGN            34.65          34.65
# 17555      JUMBO BAG STRAWBERRY                        11.70          11.70
# 17593      6 RIBBONS EMPIRE                            10.92          10.92
# 17612      MAGNETS PACK OF 4 RETRO PHOTO                6.24           6.24
# 17634      SET OF 3 CAKE TINS PANTRY DESIGN            34.65          34.65
# 17735      REGENCY CAKESTAND 3 TIER                    63.75          63.75
# 17768      PLASTERS IN TIN SPACEBOY                    46.20          46.20
# 17841      CHRISTMAS TREE HANGING SILVER                4.98           4.98
#            JUMBO BAG SCANDINAVIAN BLUE PAISLEY         10.40          10.40
#            TREASURE TIN GYMKHANA DESIGN                10.40          10.40
# 17873      WASHROOM METAL SIGN                         40.60          40.60
# 18005      VINTAGE SNAP CARDS                           4.25           4.25
# 18022      RED RETROSPOT CUP                            5.10           5.10
# 18055      WOODEN PICTURE FRAME WHITE FINISH           25.50          25.50
# 18109      FINE WICKER HEART                            7.50           7.50
# 18118      MOODY GIRL DOOR HANGER                       2.34           2.34
#            SET/10 RED POLKADOT PARTY CANDLES            6.25           6.25

# %% [markdown]
# Vale... y si quiero solo la media de una columna, es decir, solo me interesa el precio_total que se ha gastado el cliente:

# %%
dff.groupby(["customerid", 'description'])["precio_total"].mean()
# Out:
#     customerid                          description  precio_total
# 0        12395           ALARM CLOCK BAKELIKE GREEN         30.00
# 1        12412          CHILDRENS CUTLERY SPACEBOY          33.20
# 2        12476                GUMBALL MAGAZINE RACK         45.90
# 3        12534      BLUE STRIPE CERAMIC DRAWER KNOB         20.00
# 4        12540         PACK OF 12 WOODLAND TISSUES           8.12
# 5        12562            JUMBO BAG DOILEY PATTERNS         29.12
# 6        12569      SET/2 RED RETROSPOT TEA TOWELS          52.00
# 7        12614                      DOORMAT TOPIARY         47.70
# 8        12621          CHARLOTTE BAG APPLES DESIGN         20.40
# 9        12621             FELTCRAFT CUSHION RABBIT         45.00
# 10       12714          6 GIFT TAGS 50'S CHRISTMAS          13.28
# 11       12748                ILLUSTRATED CAT BOWL          12.75
# 12       12988         PLEASE ONE PERSON METAL SIGN         10.50
# 13       13004   CREAM HANGING HEART T-LIGHT HOLDER         29.50
# 14       13021  BOX OF 6 CHRISTMAS CAKE DECORATIONS         60.00
# 15       13066                  BATHROOM METAL SIGN          8.80
# 16       13313              LUNCH BAG PINK POLKADOT         23.10
# 17       13344                 GEORGIAN TRINKET BOX         75.00
# 18       13521        ANTIQUE ALL GLASS CANDLESTICK         12.60
# 19       13742            SWEETHEART WIRE WALL TIDY         79.60
# 20       13850     GIFT BAG LARGE VINTAGE CHRISTMAS         20.00
# 21       13949           3 HOOK HANGER MAGIC GARDEN         31.20
# 22       14096      SET OF 36 DOILIES PANTRY DESIGN         14.60
# 23       14096         SET OF 4 PANTRY JELLY MOULDS         12.30
# 24       14334               6 RIBBONS RUSTIC CHARM         26.40
# 25       14415                      JUMBO BAG PEARS         12.48
# 26       14482        HAND WARMER SCOTTY DOG DESIGN         10.50
# 27       14562  3 DRAWER ANTIQUE WHITE WOOD CABINET         44.75
# 28       14606      CANDLEHOLDER PINK HANGING HEART         14.75
# 29       14710        ASSORTED COLOUR BIRD ORNAMENT         16.90
# 30       14748                   WRAP MAGIC FOREST          12.18
# 31       14776  SET OF 60 I LOVE LONDON CAKE CASES          15.40
# 32       14911  SET 3 PAPER VINTAGE CHICK PAPER EGG         29.50
# 33       14936           SET OF 6 NATIVITY MAGNETS          58.24
# 34       15023               WRAP PINK FAIRY CAKES          12.18
# 35       15039                    TRELLIS COAT RACK         29.70
# 36       15039                   RED RETROSPOT BOWL          8.75
# 37       15046         SINGLE WIRE HOOK IVORY HEART         23.20
# 38       15152              ENAMEL FLOWER JUG CREAM         41.65
# 39       15277     TRADITIONAL PICK UP STICKS GAME          20.00
# 40       15382                       POPCORN HOLDER         44.20
# 41       15427                 SET/4 BADGES BEETLES          6.25
# 42       15514                GLOW IN DARK DOLPHINS          1.47
# 43       15531      PAPER CHAIN KIT 50'S CHRISTMAS          53.10
# 44       15544            LUNCH BAG ALPHABET DESIGN         23.10
# 45       15570     STAR WOODEN CHRISTMAS DECORATION          8.50
# 46       15601                   CARD CIRCUS PARADE          6.72
# 47       15639             BANQUET BIRTHDAY  CARD           11.76
# 48       15676         SET OF 3 NOTEBOOKS IN PARCEL         26.40
# 49       15719   3 PIECE SPACEBOY COOKIE CUTTER SET         10.50
# 50       15752    HEART WOODEN CHRISTMAS DECORATION         11.90
# 51       15780      CREAM WALL PLANTER HEART SHAPED         35.70
# 52       15808     ROSES REGENCY TEACUP AND SAUCER          23.60
# 53       15858        SMALL GLASS HEART TRINKET POT         25.20
# 54       15952              FRENCH ENAMEL POT W LID         14.75
# 55       16007                       JUMBO BAG OWLS         10.40
# 56       16019             REGENCY CAKESTAND 3 TIER        219.00
# 57       16033    SET OF 6 SPICE TINS PANTRY DESIGN         23.70
# 58       16070            VINTAGE CHRISTMAS BUNTING         44.55
# 59       16173            JUMBO BAG DOILEY PATTERNS         29.12
# 60       16240                   WRAP MAGIC FOREST          12.18
# 61       16253       VINTAGE SEASIDE JIGSAW PUZZLES         30.00
# 62       16327                  WHITE METAL LANTERN         30.00
# 63       16447           RIBBON REEL HEARTS DESIGN          14.85
# 64       16494  DECORATION  PINK CHICK MAGIC GARDEN          9.35
# 65       16539        DOORMAT KEEP CALM AND COME IN         99.12
# 66       16701   MAGNETS PACK OF 4 CHILDHOOD MEMORY         20.00
# 67       16712    ROUND SNACK BOXES SET OF 4 SKULLS         14.75
# 68       16713            LUNCH BAG ALPHABET DESIGN         11.55
# 69       16722                     WRAP RED APPLES          12.18
# 70       16923        LARGE CERAMIC TOP STORAGE JAR          8.25
# 71       16928      GREEN REGENCY TEACUP AND SAUCER         14.75
# 72       17034             RED METAL BOX TOP SECRET         49.50
# 73       17069      NATURAL SLATE HEART CHALKBOARD          29.50
# 74       17079                    BUNTING , SPOTTY          79.20
# 75       17086                  LUNCH BAG CARS BLUE         23.10
# 76       17092     SET OF 3 WOODEN TREE DECORATIONS         11.25
# 77       17107         SCOTTIE DOG HOT WATER BOTTLE         24.75
# 78       17119       SMALL SILVER FLOWER CANDLE POT         29.50
# 79       17358           FANCY FONT BIRTHDAY CARD,           6.72
# 80       17403     PLASTERS IN TIN VINTAGE PAISLEY           8.25
# 81       17405              PARISIENNE KEY CABINET          34.50
# 82       17406              FENG SHUI PILLAR CANDLE          1.71
# 83       17419    SET OF 3 CAKE TINS PANTRY DESIGN          34.65
# 84       17555                 JUMBO BAG STRAWBERRY         11.70
# 85       17593                   6 RIBBONS EMPIRE           10.92
# 86       17612        MAGNETS PACK OF 4 RETRO PHOTO          6.24
# 87       17634    SET OF 3 CAKE TINS PANTRY DESIGN          34.65
# 88       17735             REGENCY CAKESTAND 3 TIER         63.75
# 89       17768             PLASTERS IN TIN SPACEBOY         46.20
# 90       17841       CHRISTMAS TREE HANGING SILVER           4.98
# 91       17841  JUMBO BAG SCANDINAVIAN BLUE PAISLEY         10.40
# 92       17841         TREASURE TIN GYMKHANA DESIGN         10.40
# 93       17873                  WASHROOM METAL SIGN         40.60
# 94       18005                   VINTAGE SNAP CARDS          4.25
# 95       18022                    RED RETROSPOT CUP          5.10
# 96       18055    WOODEN PICTURE FRAME WHITE FINISH         25.50
# 97       18109                   FINE WICKER HEART           7.50
# 98       18118              MOODY GIRL DOOR HANGER           2.34
# 99       18118    SET/10 RED POLKADOT PARTY CANDLES          6.25

# %% [markdown]
# ¿Podemos almacenar estos resultados en un dataframe? Esto es pandas, claro que SI!!!!

# %%
df_customer = pd.DataFrame(dff.groupby(["customerid", 'description'])["precio_total"].mean()).reset_index()

# %%
df_customer.head()
# Out:
#    customerid                      description  precio_total
# 0       12395       ALARM CLOCK BAKELIKE GREEN         30.00
# 1       12412      CHILDRENS CUTLERY SPACEBOY          33.20
# 2       12476            GUMBALL MAGAZINE RACK         45.90
# 3       12534  BLUE STRIPE CERAMIC DRAWER KNOB         20.00
# 4       12540     PACK OF 12 WOODLAND TISSUES           8.12

# %% [markdown]
# Ahora tenemos `customerid` y `description` como índices en nuestro dataframe.
#
# ¿Recordamos como los podíamos volver a colocar como columnas? 🤔

# %%
# importamos seaborn
import seaborn as sns

# %% [markdown]
# Y con este *dataframe* ya podemos hacer cositas, como por ejemplo hacer una grafiquita de las compras de cada cliente.

# %%
sns.barplot(data = dff, x ="customerid", y = "precio_total")
# Out:
# <AxesSubplot:xlabel='customerid', ylabel='precio_total'>

# %% [markdown]
# Esto no hay quien lo entienda 🤔. Podremos filtrar por aquellos clientes que hayan gastado más de 50 euros?
#
# ¿Cómo lo haríais?

# %%
df_mejores = dff[dff["precio_total"]> 50]
df_mejores.head()
# Out:
#     customerid  invoiceno                 invoicedate stockcode  \
# 21       16539     581004  2011-12-07 08:41:00.000001     23284
# 24       17079     567888  2011-09-22 15:34:00.000000     23298
# 26       13742     555554  2011-06-05 13:46:00.000000     22829
# 32       17735     560571  2011-07-19 14:29:00.000000     22423
# 67       15531     580133  2011-12-01 18:43:00.000000     22086
#
#                         description  quantity  unitprice  revenue  \
# 21    DOORMAT KEEP CALM AND COME IN        14       7.08    70.80
# 24                BUNTING , SPOTTY         16       4.95    59.40
# 26        SWEETHEART WIRE WALL TIDY         8       9.95    39.80
# 32         REGENCY CAKESTAND 3 TIER         5      12.75    12.75
# 67  PAPER CHAIN KIT 50'S CHRISTMAS         18       2.95    41.30
#
#            country    nullid  desciption_cambiada      fecha  \
# 21  United Kingdom  333129.0                    2 2011-12-07
# 24  United Kingdom  198017.0                    2 2011-09-22
# 26  United Kingdom  131641.0                    2 2011-06-05
# 32  United Kingdom  143133.0                    2 2011-07-19
# 67  United Kingdom  198017.0                    2 2011-12-01
#
#                  coordenadas  precio_total  precio_total2
# 21  (54.7023545, -3.2765753)         99.12          99.12
# 24  (54.7023545, -3.2765753)         79.20          79.20
# 26  (54.7023545, -3.2765753)         79.60          79.60
# 32  (54.7023545, -3.2765753)         63.75          63.75
# 67  (54.7023545, -3.2765753)         53.10          53.10

# %%
# creamos nuestra nueva grafiquita

sns.barplot(data = df_mejores, x = "customerid", y = "precio_total");

# %% [markdown]
# ⚠️ En este caso hemos usado la media pero podemos aplicar otras métricas como:
#
# - count() – número de observaciones no nulas
#
#
# - sum() – suma de todos los valores
#
#
# - mean() – media de los valores
#
#
# - median() – mediana de los valores
#
#
# - min() – valor mínimo
#
#
# - max() – valor máximo
#
#
# - std() – desviación estándar
#
#
# - var() – varianza

# %% [markdown]
# Pero estos resultados puede que no sean lo que nos interesen al 100% ya que podemos estar interesados en sacar varias métricas. Pero la función `agg()` de Pandas nos da la flexibilidad de realizar varios cálculos estadísticos a la vez. Así es como funciona:

# %% [markdown]
# Imaginemos que queremos sacar la media y la mediana para cada cliente:

# %%
dff.groupby(["customerid"]).agg(["mean", "median"])
# Out:
#            invoiceno             quantity         unitprice         revenue  \
#                 mean    median       mean median       mean median     mean
# customerid
# 12395       569496.0  569496.0   8.000000    8.0   3.750000   3.75   15.000
# 12412       557889.0  557889.0   8.000000    8.0   4.150000   4.15   16.600
# 12476       578472.0  578472.0   6.000000    6.0   7.650000   7.65   15.300
# 12534       561911.0  561911.0  16.000000   16.0   1.250000   1.25   15.000
# 12540       555095.0  555095.0  28.000000   28.0   0.290000   0.29    6.960
# 12562       576941.0  576941.0  14.000000   14.0   2.080000   2.08   20.800
# 12569       570784.0  570784.0  16.000000   16.0   3.250000   3.25   39.000
# 12614       545718.0  545718.0   6.000000    6.0   7.950000   7.95   15.900
# 12621       551258.0  551258.0  18.000000   18.0   2.300000   2.30   23.500
# 12714       564372.0  564372.0  16.000000   16.0   0.830000   0.83    9.960
# 12748       547809.0  547809.0   5.000000    5.0   2.550000   2.55    2.550
# 12988       544463.0  544463.0   5.000000    5.0   2.100000   2.10    2.100
# 13004       548749.0  548749.0  10.000000   10.0   2.950000   2.95   17.700
# 13021       573907.0  573907.0  16.000000   16.0   3.750000   3.75   45.000
# 13066       576554.0  576554.0  16.000000   16.0   0.550000   0.55    6.600
# 13313       560915.0  560915.0  14.000000   14.0   1.650000   1.65   16.500
# 13344       569244.0  569244.0   6.000000    6.0  12.500000  12.50   25.000
# 13521       579472.0  579472.0   6.000000    6.0   2.100000   2.10    4.200
# 13742       555554.0  555554.0   8.000000    8.0   9.950000   9.95   39.800
# 13850       562101.0  562101.0  16.000000   16.0   1.250000   1.25   15.000
# 13949       565725.0  565725.0  16.000000   16.0   1.950000   1.95   23.400
# 14096       572426.5  572426.5   5.000000    5.0   2.690000   2.69    2.690
# 14334       546182.0  546182.0  16.000000   16.0   1.650000   1.65   19.800
# 14415       573264.0  573264.0   6.000000    6.0   2.080000   2.08    4.160
# 14482       575368.0  575368.0   5.000000    5.0   2.100000   2.10    2.100
# 14562       550994.0  550994.0   5.000000    5.0   8.950000   8.95    8.950
# 14606       554491.0  554491.0   5.000000    5.0   2.950000   2.95    2.950
# 14710       573364.0  573364.0  10.000000   10.0   1.690000   1.69   10.140
# 14748       562616.0  562616.0  29.000000   29.0   0.420000   0.42   10.500
# 14776       557220.0  557220.0  28.000000   28.0   0.550000   0.55   13.200
# 14911       548664.0  548664.0  10.000000   10.0   2.950000   2.95   17.700
# 14936       569558.0  569558.0  28.000000   28.0   2.080000   2.08   49.920
# 15023       541489.0  541489.0  29.000000   29.0   0.420000   0.42   10.500
# 15039       557534.5  557534.5   6.500000    6.5   3.100000   3.10    6.825
# 15046       562378.0  562378.0  16.000000   16.0   1.450000   1.45   17.400
# 15152       562256.0  562256.0   7.000000    7.0   5.950000   5.95   17.850
# 15277       572327.0  572327.0  16.000000   16.0   1.250000   1.25   15.000
# 15382       578702.0  578702.0  52.000000   52.0   0.850000   0.85   40.800
# 15427       574714.0  574714.0   5.000000    5.0   1.250000   1.25    1.250
# 15514       578667.0  578667.0   7.000000    7.0   0.210000   0.21    0.630
# 15531       580133.0  580133.0  18.000000   18.0   2.950000   2.95   41.300
# 15544       559814.0  559814.0  14.000000   14.0   1.650000   1.65   16.500
# 15570       539450.0  539450.0  10.000000   10.0   0.850000   0.85    5.100
# 15601       544294.0  544294.0  16.000000   16.0   0.420000   0.42    5.040
# 15639       561632.0  561632.0  28.000000   28.0   0.420000   0.42   10.080
# 15676       574532.0  574532.0  16.000000   16.0   1.650000   1.65   19.800
# 15719       574863.0  574863.0   5.000000    5.0   2.100000   2.10    2.100
# 15752       565915.0  565915.0  14.000000   14.0   0.850000   0.85    8.500
# 15780       556190.0  556190.0   6.000000    6.0   5.950000   5.95   11.900
# 15808       538660.0  538660.0   8.000000    8.0   2.950000   2.95   11.800
# 15858       578479.0  578479.0  12.000000   12.0   2.100000   2.10   16.800
# 17873         40.600000   40.600     40.600000   40.600
# 18005          4.250000    4.250      4.250000    4.250
# 18022          5.100000    5.100      5.100000    5.100
# 18055         25.500000   25.500     25.500000   25.500
# 18109          7.500000    7.500      7.500000    7.500
# 18118          4.295000    4.295      4.295000    4.295

# %% [markdown]
# ¿Y si solo quiero los estadísticos para una única columna? Por ejemplo `precio_total`?

# %%
clientes_media_mediana = dff.groupby(["customerid"])['revenue'].agg([np.mean, np.median])
clientes_media_mediana
# Out:
#                mean   median
# customerid
# 12395        15.000   15.000
# 12412        16.600   16.600
# 12476        15.300   15.300
# 12534        15.000   15.000
# 12540         6.960    6.960
# 12562        20.800   20.800
# 12569        39.000   39.000
# 12614        15.900   15.900
# 12621        23.500   23.500
# 12714         9.960    9.960
# 12748         2.550    2.550
# 12988         2.100    2.100
# 13004        17.700   17.700
# 13021        45.000   45.000
# 13066         6.600    6.600
# 13313        16.500   16.500
# 13344        25.000   25.000
# 13521         4.200    4.200
# 13742        39.800   39.800
# 13850        15.000   15.000
# 13949        23.400   23.400
# 14096         2.690    2.690
# 14334        19.800   19.800
# 14415         4.160    4.160
# 14482         2.100    2.100
# 14562         8.950    8.950
# 14606         2.950    2.950
# 14710        10.140   10.140
# 14748        10.500   10.500
# 14776        13.200   13.200
# 14911        17.700   17.700
# 14936        49.920   49.920
# 15023        10.500   10.500
# 15039         6.825    6.825
# 15046        17.400   17.400
# 15152        17.850   17.850
# 15277        15.000   15.000
# 15382        40.800   40.800
# 15427         1.250    1.250
# 15514         0.630    0.630
# 15531        41.300   41.300
# 15544        16.500   16.500
# 15570         5.100    5.100
# 15601         5.040    5.040
# 15639        10.080   10.080
# 15676        19.800   19.800
# 15719         2.100    2.100
# 15752         8.500    8.500
# 15780        11.900   11.900
# 15808        11.800   11.800
# 15858        16.800   16.800
# 15952         2.950    2.950
# 16007         2.080    2.080
# 16019       175.200  175.200
# 16033         7.900    7.900
# 16070        24.750   24.750
# 16173        20.800   20.800
# 16240        10.500   10.500
# 16253        15.000   15.000
# 16327        15.000   15.000
# 16447         8.250    8.250
# 16494         5.950    5.950
# 16539        70.800   70.800
# 16701        15.000   15.000
# 16712         2.950    2.950
# 16713         4.950    4.950
# 16722        10.500   10.500
# 16923         1.650    1.650
# 16928         2.950    2.950
# 17034        16.500   16.500
# 17069        17.700   17.700
# 17079        59.400   59.400
# 17086        16.500   16.500
# 17092         6.250    6.250
# 17107         4.950    4.950
# 17119        17.700   17.700
# 17358         5.040    5.040
# 17403         1.650    1.650
# 17405        11.500   11.500
# 17406         0.950    0.950
# 17419        14.850   14.850
# 17555         3.900    3.900
# 17593         9.360    9.360
# 17612         4.680    4.680
# 17634        14.850   14.850
# 17735        12.750   12.750
# 17768        39.600   39.600
# 17841         1.940    2.080
# 17873        34.800   34.800
# 18005         0.850    0.850
# 18022         1.700    1.700
# 18055        15.300   15.300
# 18109         2.500    2.500
# 18118         1.015    1.015

# %%
# importamos matplotlib

# %%
# creamos la nueva figura

# %%
# guardemos el csv limpito

dff.to_csv("datos/midataframelimpito.csv")

# %%
magiaaaa = pd.read_clipboard()

# %%
magiaaaa

# %%
magiaaa2 = pd.read_clipboard()

# %%
magiaaa2
# Out:
#     invoiceno          invoicedate stockcode  \
# 0      536365   2010-12-01 8:26:00    85123A
# 1      536373   2010-12-01 9:02:00    85123A
# 2      536375   2010-12-01 9:32:00    85123A
# 3      536390  2010-12-01 10:19:00    85123A
# 4      536394  2010-12-01 10:39:00    85123A
# 5      536396  2010-12-01 10:51:00    85123A
# 6      536401  2010-12-01 11:21:00    85123A
# 7      536406  2010-12-01 11:33:00    85123A
# 8      536502  2010-12-01 12:36:00    85123A
# 9      536520  2010-12-01 12:43:00    85123A
# 10     536542  2010-12-01 14:11:00    85123A
# 11     536575  2010-12-01 16:01:00    85123A
# 12     536576  2010-12-01 16:11:00    85123A
# 13     536590  2010-12-01 16:52:00    85123A
# 14     536594  2010-12-01 17:22:00    85123A
# 15     536600   2010-12-02 8:32:00    85123A
#
#                            description  quantity  unitprice  revenue  \
# 0   CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 1   CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 2   CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 3   CREAM HANGING HEART T-LIGHT HOLDER        68       2.55   163.20
# 4   CREAM HANGING HEART T-LIGHT HOLDER        36       2.55    81.60
# 5   CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
# 6   CREAM HANGING HEART T-LIGHT HOLDER         8       2.95    11.80
# 7   CREAM HANGING HEART T-LIGHT HOLDER        12       2.55    20.40
# 8   CREAM HANGING HEART T-LIGHT HOLDER        10       2.95    17.70
# 9   CREAM HANGING HEART T-LIGHT HOLDER         7       2.95     8.85
# 10  CREAM HANGING HEART T-LIGHT HOLDER        36       2.95    94.40
# 11  CREAM HANGING HEART T-LIGHT HOLDER      -124       2.55   326.40
# 12  CREAM HANGING HEART T-LIGHT HOLDER      -124       2.55   326.40
# 13  CREAM HANGING HEART T-LIGHT HOLDER        10       2.95    17.70
# 14  CREAM HANGING HEART T-LIGHT HOLDER        10       2.95    17.70
# 15  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55    15.30
#
#     customerid         country  nullid
# 0        17850  United Kingdom     NaN
# 1        17850  United Kingdom     1.0
# 2        17850  United Kingdom     NaN
# 3        17511  United Kingdom     3.0
# 4        13408  United Kingdom     NaN
# 5        17850  United Kingdom     5.0
# 6        15862  United Kingdom     NaN
# 7        17850  United Kingdom     7.0
# 8        16552  United Kingdom     NaN
# 9        14729  United Kingdom     9.0
# 10       16456  United Kingdom     NaN
# 11       13777  United Kingdom    11.0
# 12       13777  United Kingdom     NaN
# 13       13065  United Kingdom    13.0
# 14       15235  United Kingdom     NaN
# 15       17850  United Kingdom    15.0

# %%
type(magiaaa2)
# Out:
# pandas.core.frame.DataFrame

# %%
magiaaa2.dtypes
# Out:
# invoiceno        int64
# invoicedate     object
# stockcode       object
# description     object
# quantity         int64
# unitprice      float64
# revenue        float64
# customerid       int64
# country         object
# nullid         float64
# dtype: object
