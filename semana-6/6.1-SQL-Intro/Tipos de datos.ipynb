# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Tipos-de-datos-en-MySQL" data-toc-modified-id="Tipos-de-datos-en-MySQL-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Tipos de datos en MySQL</a></span><ul class="toc-item"><li><span><a href="#Datos-de-tipo-string" data-toc-modified-id="Datos-de-tipo-string-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Datos de tipo <em>string</em></a></span></li><li><span><a href="#Datos-de-tipo-numérico" data-toc-modified-id="Datos-de-tipo-numérico-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Datos de tipo numérico</a></span></li><li><span><a href="#Formato-fecha-y-hora" data-toc-modified-id="Formato-fecha-y-hora-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Formato fecha y hora</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Tipos de datos en MySQL

# %% [markdown]
# En MySQL hay tres tipos de datos principales:
#
# - *String*
#
#
# - Numéricos
#
#
# - Fecha y hora.

# %% [markdown]
# ##  Datos de tipo *string*

# %% [markdown]
# ![strings.png](attachment:strings.png)

# %% [markdown]
# ##  Datos de tipo numérico

# %% [markdown]
# ![numericos.png](attachment:numericos.png)

# %% [markdown]
# ## Formato fecha y hora
#
# ![datetime.png](attachment:datetime.png)
