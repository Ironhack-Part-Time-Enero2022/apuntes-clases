# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#¿Qué-es-Mongo-DB?" data-toc-modified-id="¿Qué-es-Mongo-DB?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>¿Qué es Mongo DB?</a></span></li><li><span><a href="#¿Cómo-nos-conectamos-con-MongoDB?" data-toc-modified-id="¿Cómo-nos-conectamos-con-MongoDB?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>¿Cómo nos conectamos con MongoDB?</a></span></li><li><span><a href="#Insertar-datos-en-Mongo-DB" data-toc-modified-id="Insertar-datos-en-Mongo-DB-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Insertar datos en Mongo DB</a></span></li><li><span><a href="#Buscar-datos-en-nuestra-BBDD." data-toc-modified-id="Buscar-datos-en-nuestra-BBDD.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Buscar datos en nuestra BBDD.</a></span><ul class="toc-item"><li><span><a href="#find()" data-toc-modified-id="find()-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span><code>find()</code></a></span><ul class="toc-item"><li><span><a href="#Búsqueda-de-campos-de-tipo-string" data-toc-modified-id="Búsqueda-de-campos-de-tipo-string-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Búsqueda de campos de tipo string</a></span></li><li><span><a href="#Búsqueda-de-campos-de-tipo-numérico" data-toc-modified-id="Búsqueda-de-campos-de-tipo-numérico-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Búsqueda de campos de tipo numérico</a></span></li></ul></li><li><span><a href="#Operadores-and-y-or" data-toc-modified-id="Operadores-and-y-or-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Operadores <code>and</code> y <code>or</code></a></span></li><li><span><a href="#Proyecciones" data-toc-modified-id="Proyecciones-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Proyecciones</a></span></li></ul></li><li><span><a href="#Otros-métodos-interesantes" data-toc-modified-id="Otros-métodos-interesantes-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Otros métodos interesantes</a></span><ul class="toc-item"><li><span><a href="#exists()" data-toc-modified-id="exists()-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span><code>exists()</code></a></span></li><li><span><a href="#limit()" data-toc-modified-id="limit()-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span><code>limit()</code></a></span></li><li><span><a href="#sort()" data-toc-modified-id="sort()-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span><code>sort()</code></a></span></li></ul></li><li><span><a href="#update()" data-toc-modified-id="update()-6"><span class="toc-item-num">6&nbsp;&nbsp;</span><code>update()</code></a></span></li><li><span><a href="#delete()" data-toc-modified-id="delete()-7"><span class="toc-item-num">7&nbsp;&nbsp;</span><code>delete()</code></a></span></li><li><span><a href="#Geoqueries" data-toc-modified-id="Geoqueries-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Geoqueries</a></span><ul class="toc-item"><li><span><a href="#Antes-de-empezar" data-toc-modified-id="Antes-de-empezar-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Antes de empezar</a></span></li><li><span><a href="#Tipos-de-geoqueries" data-toc-modified-id="Tipos-de-geoqueries-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Tipos de geoqueries</a></span><ul class="toc-item"><li><span><a href="#near()" data-toc-modified-id="near()-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span><code>near()</code></a></span></li></ul></li><li><span><a href="#geonear()" data-toc-modified-id="geonear()-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span><code>geonear()</code></a></span></li></ul></li><li><span><a href="#Ploteemos-los-resultados" data-toc-modified-id="Ploteemos-los-resultados-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Ploteemos los resultados</a></span><ul class="toc-item"><li><span><a href="#Guardar-el-mapa" data-toc-modified-id="Guardar-el-mapa-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Guardar el mapa</a></span></li></ul></li></ul></div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # ¿Qué es Mongo DB?

# %% [markdown]
# MongoDB es la base de datos no relacional, que nos permite:
#
# - Aprovechar los datos y la tecnología para maximizar la ventaja competitiva
#
#
# - Reducir el riesgo de implementaciones de misión crítica
#
#
# - Acelerar el tiempo de valor drásticamente, menor costo total de propiedad
#
# A diferencia de las bases de datos relacionales, donde se almacenan los registros como filas de una tabla, con MongoDB estos registros son almacenados en documentos BSON (un derivado de los documentos JSON).
#
# Veámos los conceptos básicos presentes en MongoDB:
#
# - Los `documentos`: cada una de las entradas de nuestra colección.
#
#
# - Las `colecciones`: es un conjunto de documentos y podría identificarse con una tabla con la particularidad de que no existe un esquema fijo (es decir, el número de campos y sus nombres pueden variar)
#
#
# - Las `bases de datos`: conjunto de colecciones

# %% [markdown]
# # ¿Cómo nos conectamos con MongoDB?

# %% [markdown]
# Pymongo es un driver de Python para MongoDB que permite interactuar con las bases de datos Mongo usando Python. Primero necesitas tener instalado MongoDB en tu sistema.

# %%
# lo primero que tenemos que hacer es instalar pymongo

# !pip install pymongo

# %%
# importamos la librería

import pymongo

# %%
# nos conectamos con Mongo

cliente = pymongo.MongoClient()
cliente
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
# vamos a chequear que bases de datos tenemos 

cliente.list_database_names()
# Out:
# ['APISPECIES',
#  'Diabetes',
#  'National_Parks',
#  'admin',
#  'algae',
#  'alojamientos',
#  'barrios',
#  'companies',
#  'company',
#  'config',
#  'final',
#  'geo',
#  'local',
#  'numeros']

# %%
# creamos una base de datos nueva
mydb = cliente["alojamientos"]

# %%
# creamos una coleccion dentro de la BBDD

coleccion = mydb.detalles

# %% [markdown]
# # Insertar datos en Mongo DB
#
# Tenemos dos métodos para hacer esto:
#
# - `insert_one()`
#
#
# - `insert_many()`

# %% [markdown]
# **insert_one()** lo utilizamos para insertar un único documento en nuestra colección

# %%
dictio={'nombre':' Juan', 'edad':25}

coleccion.insert_one(dictio)

# %% [markdown]
# **insert_many()** lo utilizamos para insertar más de un documento en nuestra colección

# %%
varios = [{"nombre": "Maria", "apellidos": "López", "edad": 43, 
           "dirección": "Calle de Arenas", "provincia": "Madrid"},
          
          {'nombre':"Lorenzo", 'apellidos': "Hernández", "edad": 23, 
           "direccion": "Calle de Arenas de San Pedro", "provicia": "madrid" }]

# %%
coleccion.insert_many(varios)

# %% [markdown]
# También podemos insertar datos desde un *dataframe*. Vamos a cargar un csv donde tenemos los datos que queremos insertar

# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
df = pd.read_csv("data/alojamientos.csv")
df.head(2)
# Out:
#    fid                                 etiqueta  granularidad cod_tipocat  \
# 0    0  HOTEL RIU CLUB PARAISO LANZAROTE RESORT  ALOJAMIENTOS          H4
# 1    1               OCCIDENTAL LANZAROTE PLAYA  ALOJAMIENTOS          H4
#
#   cod_tipo nom_tipo  cod_categor  nom_categor gcd_isla   nom_isla gcd_entitur  \
# 0  5510_L1    Hotel            4  4 Estrellas    ES708  Lanzarote     ES708B2
# 1  5510_L1    Hotel            4  4 Estrellas    ES708  Lanzarote     ES708B1
#
#          nom_entitur gcd_nucltur                                  nom_nucltur  \
# 0  Puerto del Carmen    ES708B23  Puerto del Carmen: Matagorda - Los Pocillos
# 1      Costa Teguise    ES708B12                       Costa Teguise: Litoral
#
#    gcd_municipio nom_municipio                              direccion  \
# 0          35028          Tías  CALLE SUIZA , 4.PLAYA DE LOS POCILLOS
# 1          35024       Teguise                     AVENIDA DEL MAR, 6
#
# ...

# %%
coleccion.insert_many(df.to_dict("records"))

# %% [markdown]
# Si volvemos a `MongoDB Compass` se nos actualiza la colección con todas las entradas de nuestro *dataframe*

# %% [markdown]
# ![Captura%20de%20pantalla%202022-02-07%20a%20las%2014.44.47.png](attachment:Captura%20de%20pantalla%202022-02-07%20a%20las%2014.44.47.png)

# %% [markdown]
# # Buscar datos en nuestra BBDD.

# %% [markdown]
# ## `find()`
#
# El método `find()` devuelve todas las ocurrencias que coincidan con nuestra búsqueda.
#
# ```pyhton
# micoleccion.find({campo1: filtro, campo2: filtro ... })
# ```

# %%
# si pasamos el parámetro de consulta sin niguna especificación, nos devolverá todos los elementos de la BBDD

coleccion.find()

# %%
list(coleccion.find())[3]
# Out:
# {'_id': ObjectId('6203dc2bb487369260ef82db'),
#  'fid': 3,
#  'etiqueta': 'HOTEL CATALONIA PUNTA DEL REY',
#  'granularidad': 'ALOJAMIENTOS',
#  'cod_tipocat': 'H4',
#  'cod_tipo': '5510_L1',
#  'nom_tipo': 'Hotel',
#  'cod_categor': 4,
#  'nom_categor': '4 Estrellas',
#  'gcd_isla': 'ES709',
#  'nom_isla': 'Tenerife',
#  'gcd_entitur': 'ES709B9',
#  'nom_entitur': 'Resto de Tenerife',
#  'gcd_nucltur': 'ES709B9',
#  'nom_nucltur': 'Resto de Tenerife',
#  'gcd_municipio': 38011,
#  'nom_municipio': 'Candelaria',
#  'direccion': 'AVENIDA GENERALISIMO, 165',
#  'prc_habita': '300 o más habitaciones',
#  'prc_plazas': '650 o más plazas',
#  'longitud': -16.36211189,
#  'latitud': 28.377361794,
#  'geohash': 'eth37tvqp5',
#  'utm_x': 366536.23,
#  'utm_y': 3139759.91,
#  'geometria': {'type': 'Point', 'coordinates': [-16.36211189, 28.377361794]}}

# %% [markdown]
# Imaginemos ahora que queremos filtrar los alojamientos de una isla en concreto, pero no sabemos que valores tenemos en concreto en ese campo. Lo primero que haremos será evaluar los valores únicos que tenemos en ese campo. Para eso usaremos el método `distinct`
#
# ```python
# micoleccion.distinct( "nombredelcampo" )
# ```

# %%
coleccion.distinct( "nom_isla" )
# Out:
# ['El Hierro',
#  'Fuerteventura',
#  'Gran Canaria',
#  'La Gomera',
#  'La Palma',
#  'Lanzarote',
#  'Tenerife']

# %% [markdown]
# ### Búsqueda de campos de tipo string

# %% [markdown]
# Ahora ya lo tenemos claro, y queremos sacar todos los alojamientos de la isla de "El Hierro".

# %%
list(coleccion.find({"nom_isla":"El Hierro"}))[:2]
# Out:
# [{'_id': ObjectId('6203dc2bb487369260ef8317'),
#   'fid': 63,
#   'etiqueta': 'PENSION CARIBE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES703',
#   'nom_isla': 'El Hierro',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38013,
#   'nom_municipio': 'Frontera',
#   'direccion': 'PUNTA GRANDE, 1',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -17.99066516,
#   'latitud': 27.796579285,
#   'geohash': 'esgnns5wg1',
#   'utm_x': 205323.77,
#   'utm_y': 3078257.25,
#   'geometria': {'type': 'Point', 'coordinates': [-17.99066516, 27.796579285]}},
#  {'_id': ObjectId('6203dc2bb487369260ef8318'),
#   'fid': 64,
# ...

# %% [markdown]
# ### Búsqueda de campos de tipo numérico

# %% [markdown]
# Para hacer búsquedas con valores númericos tendremos que usar los operadores de comparación, que en Mongo son un poco diferentes:
#
# - `$eq`: igual a
#
#
# - `$gt`: mayor que
#
#
# - `$gte`: mayor o igual que
#
#
# - `$lt`: menor que
#
#
# - `$lte`: menor o igual que
#
#
# - `$in`: dentro de
#
#
# - `$nin`: no dentro de
#
#
# - `$ne`: distinto de

# %% [markdown]
# 1️⃣ `$eq`: igual a
#
# Busquemos aquellos alojamientos que tengan 3⭐️

# %%
list(coleccion.find({'cod_categor': {"$eq": 3}} ))[:2]
# Out:
# [{'_id': ObjectId('6203dc2bb487369260ef82dc'),
#   'fid': 4,
#   'etiqueta': 'HOTEL MEDANO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B3',
#   'nom_entitur': 'Abona',
#   'gcd_nucltur': 'ES709B32',
#   'nom_nucltur': 'El Médano',
#   'gcd_municipio': 38017,
#   'nom_municipio': 'Granadilla de Abona',
#   'direccion': 'PASEO PICACHO, 2',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.53800193,
#   'latitud': 28.044016879,
#   'geohash': 'esupx9m2hx',
#   'utm_x': 348831.06,
#   'utm_y': 3103032.41,
#   'geometria': {'type': 'Point', 'coordinates': [-16.53800193, 28.044016879]}},
#  {'_id': ObjectId('6203dc2bb487369260ef82dd'),
#   'fid': 5,
#   'etiqueta': 'HOTEL PLAYA SUR TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
# ...

# %% [markdown]
# 2️⃣ `$gt`: mayor que
#
# Busquemos aquellos alojamientos que tengan mas de 3⭐️

# %%
mayor = pd.DataFrame(coleccion.find({'cod_categor': {"$gt": 3}}))
mayor.head(2)
# Out:
#                         _id  fid                                 etiqueta  \
# 0  6203dc2bb487369260ef82d8    0  HOTEL RIU CLUB PARAISO LANZAROTE RESORT
# 1  6203dc2bb487369260ef82d9    1               OCCIDENTAL LANZAROTE PLAYA
#
#    granularidad cod_tipocat cod_tipo nom_tipo  cod_categor  nom_categor  \
# 0  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 1  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
#
#   gcd_isla   nom_isla gcd_entitur        nom_entitur gcd_nucltur  \
# 0    ES708  Lanzarote     ES708B2  Puerto del Carmen    ES708B23
# 1    ES708  Lanzarote     ES708B1      Costa Teguise    ES708B12
#
#                                    nom_nucltur  gcd_municipio nom_municipio  \
# 0  Puerto del Carmen: Matagorda - Los Pocillos          35028          Tías
# 1                       Costa Teguise: Litoral          35024       Teguise
#
#                                direccion              prc_habita  \
# ...

# %%
mayor.nom_categor.unique()
# Out:
# array(['4 Estrellas', '5 Estrellas'], dtype=object)

# %% [markdown]
# 3️⃣ `$gte`: mayor o igual que
#
# Busquemos aquellos alojamientos que tengan 3 o mas ⭐️

# %%
mayor_igual = pd.DataFrame(coleccion.find({'cod_categor': {"$gte": 3}}))
mayor_igual.head(2)
# Out:
#                         _id  fid                                 etiqueta  \
# 0  6203dc2bb487369260ef82d8    0  HOTEL RIU CLUB PARAISO LANZAROTE RESORT
# 1  6203dc2bb487369260ef82d9    1               OCCIDENTAL LANZAROTE PLAYA
#
#    granularidad cod_tipocat cod_tipo nom_tipo  cod_categor  nom_categor  \
# 0  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 1  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
#
#   gcd_isla   nom_isla gcd_entitur        nom_entitur gcd_nucltur  \
# 0    ES708  Lanzarote     ES708B2  Puerto del Carmen    ES708B23
# 1    ES708  Lanzarote     ES708B1      Costa Teguise    ES708B12
#
#                                    nom_nucltur  gcd_municipio nom_municipio  \
# 0  Puerto del Carmen: Matagorda - Los Pocillos          35028          Tías
# 1                       Costa Teguise: Litoral          35024       Teguise
#
#                                direccion              prc_habita  \
# ...

# %%
mayor_igual.nom_categor.unique()
# Out:
# array(['4 Estrellas', '3 Estrellas', '5 Estrellas'], dtype=object)

# %% [markdown]
# 4️⃣ `$lt`: menor que
#
# Busquemos aquellos alojamientos que tengan menos de 3⭐️

# %%
menor = pd.DataFrame(coleccion.find({'cod_categor': {"$lt": 3}}))
menor.head(2)
# Out:
#                         _id  fid                               etiqueta  \
# 0  6203dc2bb487369260ef82de    6  PARADOR TURISMO LAS CAÑADAS DEL TEIDE
# 1  6203dc2bb487369260ef82df    7                     HOTEL SUN HOLIDAYS
#
#    granularidad cod_tipocat cod_tipo nom_tipo  cod_categor  nom_categor  \
# 0  ALOJAMIENTOS          H2  5510_L1    Hotel            2  2 Estrellas
# 1  ALOJAMIENTOS          H1  5510_L1    Hotel            1   1 Estrella
#
#   gcd_isla  nom_isla gcd_entitur                  nom_entitur gcd_nucltur  \
# 0    ES709  Tenerife     ES709B9            Resto de Tenerife     ES709B9
# 1    ES709  Tenerife     ES709B5  Puerto de la Cruz turístico    ES709B52
#
#           nom_nucltur  gcd_municipio      nom_municipio  \
# 0   Resto de Tenerife          38026         La Orotava
# 1  Conjunto Histórico          38028  Puerto de la Cruz
#
#                      direccion                prc_habita           prc_plazas  \
# ...

# %%
menor.nom_categor.unique()
# Out:
# array(['2 Estrellas', '1 Estrella'], dtype=object)

# %% [markdown]
# 5️⃣ `$lte`: menor que
#
# Busquemos aquellos alojamientos que tengan 3 o menos ⭐️

# %%
menor_igual = pd.DataFrame(coleccion.find({'cod_categor': {"$lte": 3}}))
menor_igual.head(2)
# Out:
#                         _id  fid                  etiqueta  granularidad  \
# 0  6203dc2bb487369260ef82dc    4              HOTEL MEDANO  ALOJAMIENTOS
# 1  6203dc2bb487369260ef82dd    5  HOTEL PLAYA SUR TENERIFE  ALOJAMIENTOS
#
#   cod_tipocat cod_tipo nom_tipo  cod_categor  nom_categor gcd_isla  nom_isla  \
# 0          H3  5510_L1    Hotel            3  3 Estrellas    ES709  Tenerife
# 1          H3  5510_L1    Hotel            3  3 Estrellas    ES709  Tenerife
#
#   gcd_entitur nom_entitur gcd_nucltur nom_nucltur  gcd_municipio  \
# 0     ES709B3       Abona    ES709B32   El Médano          38017
# 1     ES709B3       Abona    ES709B32   El Médano          38017
#
#          nom_municipio              direccion                prc_habita  \
# 0  Granadilla de Abona       PASEO PICACHO, 2  De 50 a 149 habitaciones
# 1  Granadilla de Abona  PLAYA DEL MÉDANO, S/N  De 50 a 149 habitaciones
#
#             prc_plazas   longitud    latitud     geohash      utm_x  \
# ...

# %%
menor_igual.nom_categor.unique()
# Out:
# array(['3 Estrellas', '2 Estrellas', '1 Estrella'], dtype=object)

# %% [markdown]
# 6️⃣ `in()`: dentro de
#
# Queremos sacar todos los alojamientos que están en Lanzarote y en El Hierro

# %%
# creamos una lista con las islas que queremos buscar.

islas = ["Lanzarote", "El Hierro"]

# %%
list(coleccion.find({"nom_isla": {"$in": islas}}))[:3]
# Out:
# [{'_id': ObjectId('6203dc2bb487369260ef82d8'),
#   'fid': 0,
#   'etiqueta': 'HOTEL RIU CLUB PARAISO LANZAROTE RESORT',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B23',
#   'nom_nucltur': 'Puerto del Carmen: Matagorda - Los Pocillos',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE SUIZA , 4.PLAYA DE LOS POCILLOS',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -13.63932784,
#   'latitud': 28.926763238,
#   'geohash': 'etnk99unse',
#   'utm_x': 632629.37,
#   'utm_y': 3200633.49,
#   'geometria': {'type': 'Point', 'coordinates': [-13.63932784, 28.926763238]}},
#  {'_id': ObjectId('6203dc2bb487369260ef82d9'),
#   'fid': 1,
# ...

# %% [markdown]
# 7️⃣ `nin()` no dentro de.
#
# Hace referencia a:
#
# - el valor del campo no está
#
#
# - el campo no existe
#
#
# Imaginemos que queremos buscar todas las islas. Podríamos hacer un `find` e indicar el nombre de todas las islas. También podemos usar `nin` y especificar solo el que no queremo

# %%
list(coleccion.find({"nom_isla": {"$nin": ["Lanzarote"]}}))[:3]
# Out:
# [{'_id': ObjectId('6203dc2bb487369260ef82da'),
#   'fid': 2,
#   'etiqueta': 'HOTEL PARADISE PARK',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B23',
#   'nom_nucltur': 'Los Cristianos',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'URBANIZACIÓN OASIS DEL SUR',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.70628369,
#   'latitud': 28.053428781,
#   'geohash': 'esupeffz56',
#   'utm_x': 332302.78,
#   'utm_y': 3104295.54,
#   'geometria': {'type': 'Point', 'coordinates': [-16.70628369, 28.053428781]}},
#  {'_id': ObjectId('6203dc2bb487369260ef82db'),
#   'fid': 3,
#   'etiqueta': 'HOTEL CATALONIA PUNTA DEL REY',
# ...

# %% [markdown]
# 8️⃣ `$ne`: distinto de
#
# Si quisieramos hacer una búsqueda como la anterior también podemos usar. Buscaremos todo lo que sea distinto de Lanzarote

# %%
list(coleccion.find({"nom_isla": {"$ne": ["Lanzarote"]}}))[3:6]
# Out:
# [{'_id': ObjectId('6203dc2bb487369260ef82db'),
#   'fid': 3,
#   'etiqueta': 'HOTEL CATALONIA PUNTA DEL REY',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38011,
#   'nom_municipio': 'Candelaria',
#   'direccion': 'AVENIDA GENERALISIMO, 165',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.36211189,
#   'latitud': 28.377361794,
#   'geohash': 'eth37tvqp5',
#   'utm_x': 366536.23,
#   'utm_y': 3139759.91,
#   'geometria': {'type': 'Point', 'coordinates': [-16.36211189, 28.377361794]}},
#  {'_id': ObjectId('6203dc2bb487369260ef82dc'),
#   'fid': 4,
#   'etiqueta': 'HOTEL MEDANO',
# ...

# %% [markdown]
# ## Operadores `and` y `or`

# %% [markdown]
# Combinemos dos condiciones, aquí podemos usar dos operadores:
#
# - `$and`: se tienen que cumplir todas las condiciones que le pasamos
#
#
# - `$or`: que se cumpla una condición u otra

# %%
cond1 = {"nom_isla":"El Hierro"}
cond2 = {'cod_categor': {"$eq": 3}}

list(coleccion.find({'$and': [cond1, cond2]}))
# Out:
# [{'_id': ObjectId('6203dc2bb487369260ef84f8'),
#   'fid': 544,
#   'etiqueta': 'PARADOR DE TURISMO DE EL HIERRO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES703',
#   'nom_isla': 'El Hierro',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38048,
#   'nom_municipio': 'Valverde',
#   'direccion': 'CALLE LAS PLAYAS 15',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -17.95844378,
#   'latitud': 27.717393744,
#   'geohash': 'esgjxmg19b',
#   'utm_x': 208288.94,
#   'utm_y': 3069402.13,
#   'geometria': {'type': 'Point', 'coordinates': [-17.95844378, 27.717393744]}},
#  {'_id': ObjectId('6203dec9c43d082d7be0f071'),
#   'fid': 544,
# ...

# %%
list(coleccion.find({'$or': [cond1, cond2]}))[5:7]
# Out:
# [{'_id': ObjectId('6203dc2bb487369260ef82e9'),
#   'fid': 17,
#   'etiqueta': 'HOTEL NOPAL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE SAN JUAN, 15',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54944003,
#   'latitud': 28.41584195,
#   'geohash': 'eth1xkvn60',
#   'utm_x': 348233.79,
#   'utm_y': 3144245.39,
#   'geometria': {'type': 'Point', 'coordinates': [-16.54944003, 28.41584195]}},
#  {'_id': ObjectId('6203dc2bb487369260ef82eb'),
#   'fid': 19,
#   'etiqueta': 'HOTEL SAN BORONDON',
# ...

# %% [markdown]
# ## Proyecciones

# %% [markdown]
# Haremos proyecciones cuando no queramos que nos devuelvan todos los campos de nuestro documento.

# %%
list(coleccion.find({'$or': [cond1, cond2]}, {"etiqueta":1,"_id":0}))[8:20]
# Out:
# [{'etiqueta': 'HOTEL APART. PANORAMICA GARDEN'},
#  {'etiqueta': 'HOTEL BARCELÓ SANTA CRUZ CONTEMPORANEO'},
#  {'etiqueta': 'HOTEL ADONIS PLAZA'},
#  {'etiqueta': 'HOTEL AEROPUERTO SUR'},
#  {'etiqueta': 'HOTEL PRINCIPE PAZ'},
#  {'etiqueta': 'HOTEL ROBINSON CLUB JANDIA PLAYA'},
#  {'etiqueta': 'HOTEL PERLA TENERIFE'},
#  {'etiqueta': 'HOTEL APART. VILLA DE ADEJE BEACH'},
#  {'etiqueta': 'HOTEL TORRE DEL CONDE'},
#  {'etiqueta': 'HOTEL CATALONIA ORO NEGRO'},
#  {'etiqueta': 'HOTEL APART. ASTORIA'},
#  {'etiqueta': 'HOTEL APART. DRAGOS DEL SUR'}]

# %% [markdown]
# # Otros métodos interesantes

# %% [markdown]
# ## `exists()`
#
# Si no quiero que me devuelva los que no tienen o no determinado campo
#
# En este caso queremos filtrar por aquellos campos que tienen el campo "nombre"

# %%
list(coleccion.find({'nombre': {'$exists': True}}))
# Out:
# [{'_id': ObjectId('6203dec9c43d082d7be0ee4e'), 'nombre': ' Juan', 'edad': 25},
#  {'_id': ObjectId('6203dec9c43d082d7be0ee4f'),
#   'nombre': 'Maria',
#   'apellidos': 'López',
#   'edad': 43,
#   'dirección': 'Calle de Arenas',
#   'provincia': 'Madrid'},
#  {'_id': ObjectId('6203dec9c43d082d7be0ee50'),
#   'nombre': 'Lorenzo',
#   'apellidos': 'Hernández',
#   'edad': 23,
#   'direccion': 'Calle de Arenas de San Pedro',
#   'provicia': 'madrid'}]

# %% [markdown]
# ## `limit()`

# %%
list(coleccion.find().limit(3))
# Out:
# [{'_id': ObjectId('6203dc2bb487369260ef82d8'),
#   'fid': 0,
#   'etiqueta': 'HOTEL RIU CLUB PARAISO LANZAROTE RESORT',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B23',
#   'nom_nucltur': 'Puerto del Carmen: Matagorda - Los Pocillos',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE SUIZA , 4.PLAYA DE LOS POCILLOS',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -13.63932784,
#   'latitud': 28.926763238,
#   'geohash': 'etnk99unse',
#   'utm_x': 632629.37,
#   'utm_y': 3200633.49,
#   'geometria': {'type': 'Point', 'coordinates': [-13.63932784, 28.926763238]}},
#  {'_id': ObjectId('6203dc2bb487369260ef82d9'),
#   'fid': 1,
# ...

# %% [markdown]
# ## `sort()`
#
# El sentido del orden los especificaremos pasando un `1` o un `-1`.
#
# - `1`: orden ascendente.
#
#
# - `-1`: orden descendente.

# %%
list(coleccion.find({'cod_categor': {"$lt": 3}}).sort("cod_categor", 1))[:3]
# Out:
# [{'_id': ObjectId('6203dc2bb487369260ef82df'),
#   'fid': 7,
#   'etiqueta': 'HOTEL SUN HOLIDAYS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE LA PEÑITA, 6',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.55375492,
#   'latitud': 28.416832449,
#   'geohash': 'eth1xm1uj9',
#   'utm_x': 347812.51,
#   'utm_y': 3144360.59,
#   'geometria': {'type': 'Point', 'coordinates': [-16.55375492, 28.416832449]}},
#  {'_id': ObjectId('6203dc2bb487369260ef82e1'),
#   'fid': 9,
#   'etiqueta': 'APARTAMENTOS BAMBI',
# ...

# %%
list(coleccion.find({'cod_categor': {"$lt": 3}}).sort("cod_categor", -1))[:3]
# Out:
# [{'_id': ObjectId('6203dc2bb487369260ef82de'),
#   'fid': 6,
#   'etiqueta': 'PARADOR TURISMO LAS CAÑADAS DEL TEIDE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H2',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 2,
#   'nom_categor': '2 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38026,
#   'nom_municipio': 'La Orotava',
#   'direccion': 'CALLE LAS CAÑADAS DEL TEIDE',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.62713435,
#   'latitud': 28.224399963,
#   'geohash': 'eth0tdh7p9',
#   'utm_x': 340336.74,
#   'utm_y': 3123133.08,
#   'geometria': {'type': 'Point', 'coordinates': [-16.62713435, 28.224399963]}},
#  {'_id': ObjectId('6203dc2bb487369260ef8319'),
#   'fid': 65,
#   'etiqueta': 'PENSION CASAÑAS',
# ...

# %% [markdown]
# # `update()`
#
#
# Nos va a ayudar a actualizar un entrada de nuestra colección.

# %%
coleccion.update_one({'fid':0}, {'$set': {'cod_categor': 5 }})

# %%
# comprobemos si se hizo el cambio

list(coleccion.find({'fid':0}))
# Out:
# [{'_id': ObjectId('6203dc2bb487369260ef82d8'),
#   'fid': 0,
#   'etiqueta': 'HOTEL RIU CLUB PARAISO LANZAROTE RESORT',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B23',
#   'nom_nucltur': 'Puerto del Carmen: Matagorda - Los Pocillos',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE SUIZA , 4.PLAYA DE LOS POCILLOS',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -13.63932784,
#   'latitud': 28.926763238,
#   'geohash': 'etnk99unse',
#   'utm_x': 632629.37,
#   'utm_y': 3200633.49,
#   'geometria': {'type': 'Point', 'coordinates': [-13.63932784, 28.926763238]}},
#  {'_id': ObjectId('6203dec9c43d082d7be0ee51'),
#   'fid': 0,
# ...

# %% [markdown]
# # `delete()`
#
# Eliminamos una entrada de nuestra colección

# %%
coleccion.delete_one({'nombre':"Maria"})

# %%
# comprobemos si se hizo el cambio

list(coleccion.find({'nombre':"Maria"}))
# Out:
# []

# %% [markdown]
# # Geoqueries

# %% [markdown]
# ## Antes de empezar

# %% [markdown]
# Antes de ponernos a trabajar en geoqueries tenemos que hacer algunas cositas:
#
# - 1️⃣ Para poder hacer las geoqueries tenemos que tener una columna con las coordenadas con la siguiente estructura 👇🏽:
#
# ![Captura%20de%20pantalla%202022-02-07%20a%20las%207.13.45.png](attachment:Captura%20de%20pantalla%202022-02-07%20a%20las%207.13.45.png)
#
#
# - 2️⃣ Crear los índices

# %% [markdown]
# 1️⃣ Crear la geometría

# %%
def crear_geometria(lon,lat):
    return {"type": "Point", "coordinates":[ lon, lat]}

# %%
df.head(1)
# Out:
#    fid                                 etiqueta  granularidad cod_tipocat  \
# 0    0  HOTEL RIU CLUB PARAISO LANZAROTE RESORT  ALOJAMIENTOS          H4
#
#   cod_tipo nom_tipo  cod_categor  nom_categor gcd_isla   nom_isla gcd_entitur  \
# 0  5510_L1    Hotel            4  4 Estrellas    ES708  Lanzarote     ES708B2
#
#          nom_entitur gcd_nucltur                                  nom_nucltur  \
# 0  Puerto del Carmen    ES708B23  Puerto del Carmen: Matagorda - Los Pocillos
#
#    gcd_municipio nom_municipio                              direccion  \
# 0          35028          Tías  CALLE SUIZA , 4.PLAYA DE LOS POCILLOS
#
#                prc_habita        prc_plazas   longitud    latitud     geohash  \
# 0  300 o más habitaciones  650 o más plazas -13.639328  28.926763  etnk99unse
#
#        utm_x       utm_y
# 0  632629.37  3200633.49

# %%
df_geometry = df.copy()

# %% [markdown]
# **No se podrán hacer los índices más adelante si tenemos NaN, por lo que lo primero vamos a eliminar esos nulos**

# %%
df_geometry.isnull().sum()
# Out:
# fid              0
# etiqueta         0
# granularidad     0
# cod_tipocat      0
# cod_tipo         0
# nom_tipo         0
# cod_categor      0
# nom_categor      0
# gcd_isla         0
# nom_isla         0
# gcd_entitur      0
# nom_entitur      0
# gcd_nucltur      0
# nom_nucltur      0
# gcd_municipio    0
# nom_municipio    0
# direccion        0
# prc_habita       0
# prc_plazas       0
# longitud         2
# latitud          2
# geohash          2
# utm_x            2
# utm_y            2
# dtype: int64

# %%
df_geometry.dropna(how = "any", inplace = True)

# %%
df_geometry.isnull().sum()
# Out:
# fid              0
# etiqueta         0
# granularidad     0
# cod_tipocat      0
# cod_tipo         0
# nom_tipo         0
# cod_categor      0
# nom_categor      0
# gcd_isla         0
# nom_isla         0
# gcd_entitur      0
# nom_entitur      0
# gcd_nucltur      0
# nom_nucltur      0
# gcd_municipio    0
# nom_municipio    0
# direccion        0
# prc_habita       0
# prc_plazas       0
# longitud         0
# latitud          0
# geohash          0
# utm_x            0
# utm_y            0
# dtype: int64

# %%
df_geometry["geometria"] = df_geometry.apply(lambda datos: crear_geometria(
                                    datos["longitud"],
                                    datos["latitud"]), axis = 1)

# %%
df_geometry.head(1)
# Out:
#    fid                                 etiqueta  granularidad cod_tipocat  \
# 0    0  HOTEL RIU CLUB PARAISO LANZAROTE RESORT  ALOJAMIENTOS          H4
#
#   cod_tipo nom_tipo  cod_categor  nom_categor gcd_isla   nom_isla gcd_entitur  \
# 0  5510_L1    Hotel            4  4 Estrellas    ES708  Lanzarote     ES708B2
#
#          nom_entitur gcd_nucltur                                  nom_nucltur  \
# 0  Puerto del Carmen    ES708B23  Puerto del Carmen: Matagorda - Los Pocillos
#
#    gcd_municipio nom_municipio                              direccion  \
# 0          35028          Tías  CALLE SUIZA , 4.PLAYA DE LOS POCILLOS
#
#                prc_habita        prc_plazas   longitud    latitud     geohash  \
# 0  300 o más habitaciones  650 o más plazas -13.639328  28.926763  etnk99unse
#
#        utm_x       utm_y                                          geometria
# 0  632629.37  3200633.49  {'type': 'Point', 'coordinates': [-13.63932784...

# %% [markdown]
# Lo que vamos a hacer ahora es eliminar la colección y volver a meter los datos:

# %%
coleccion.drop()

# %%
# creamos la base de datos
mydb = cliente["alojamientos"]

# creamos la coleccion
coleccion = mydb.detalles

# %%
# volvemos a insertar los datos
coleccion.insert_many(df_geometry.to_dict("records"))

# %% [markdown]
# 2️⃣ Crear el índice
#
# Lo podemos hacer de dos formas:
#
# - A través de código desde jupyter
#
#
# - A través de la interfaz de Mongo

# %%
# a través de jupyter
coleccion.create_index([('geometria', '2dsphere')])
# Out:
# 'geometria_2dsphere'

# %%
# a través de la interfaz

# %% [markdown]
# - Nos vamos a la pestaña de `Indexes` y pichamos en `CREATE INDEX`
#
# ![Captura%20de%20pantalla%202022-02-07%20a%20las%207.37.01.png](attachment:Captura%20de%20pantalla%202022-02-07%20a%20las%207.37.01.png)

# %% [markdown]
# - Seleccionamos el campo sobre el que queremos crear el índice. En nuestro caso: `geometria.coordinates`
# ![Captura%20de%20pantalla%202022-02-07%20a%20las%207.39.19.png](attachment:Captura%20de%20pantalla%202022-02-07%20a%20las%207.39.19.png)

# %% [markdown]
# - seleccionamos el tipo de geometria, normalmente haremos un `2d-sphere`
#
# ![Captura%20de%20pantalla%202022-02-07%20a%20las%207.40.18.png](attachment:Captura%20de%20pantalla%202022-02-07%20a%20las%207.40.18.png)

# %% [markdown]
# - Por último ponemos nombre al índice que hemos creado:
#
# ![Captura%20de%20pantalla%202022-02-07%20a%20las%207.41.16.png](attachment:Captura%20de%20pantalla%202022-02-07%20a%20las%207.41.16.png)

# %% [markdown]
# ## Tipos de geoqueries
#
# - `near`: especifica un punto para el que una consulta geoespacial devuelve los documentos desde el más cercano al más lejano. El operador `$near` puede especificar un punto GeoJSON o un punto de coordenadas heredado.
#
#
#
# - `geonear`: muestra los documentos en orden de más cercano a más lejano de un punto especificado. Además nos va a incluir una columna más indicando los metros de distancia que hay entre el punto de referencia y cada uno de los de nuestra colección

# %% [markdown]
# ### `near()`
#
# Necesitaremos:
#
# - Unas coordenadas de referencia (en nuestro ejemplo geopoint). Recordamos que tienen que estar en formato de geopunto
#
#
# - Unos metros máximos o mínimos de distancia (en nuestro ejemplo metros)

# %%
# definimos el punto sobre el que queremos hacer nuestra búsqueda

geopoint = {'type': 'Point', 'coordinates':[-15.438072, 28.122201]}
metros = 3000

# %%
busqueda = coleccion.find({'geometria':{
        '$near': {'$geometry': geopoint, '$maxDistance':metros}
    }})
busqueda

# %%
resultado = pd.DataFrame(busqueda)

# %%
resultado.shape
# Out:
# (30, 26)

# %%
resultado.head(2)
# Out:
#                         _id  fid                             etiqueta  \
# 0  6203decac43d082d7be0f364  625           HOTEL BOUTIQUE CASA MOZART
# 1  6203decac43d082d7be0f1df  234  HOTEL SANTA CATALINA ROYAL HIDEAWAY
#
#    granularidad cod_tipocat cod_tipo nom_tipo  cod_categor  nom_categor  \
# 0  ALOJAMIENTOS          H3  5510_L1    Hotel            3  3 Estrellas
# 1  ALOJAMIENTOS          H5  5510_L1    Hotel            5  5 Estrellas
#
#   gcd_isla      nom_isla gcd_entitur            nom_entitur gcd_nucltur  \
# 0    ES705  Gran Canaria     ES705B9  Resto de Gran Canaria     ES705B9
# 1    ES705  Gran Canaria     ES705B9  Resto de Gran Canaria     ES705B9
#
#              nom_nucltur  gcd_municipio               nom_municipio  \
# 0  Resto de Gran Canaria          35016  Las Palmas de Gran Canaria
# 1  Resto de Gran Canaria          35016  Las Palmas de Gran Canaria
#
#                     direccion                 prc_habita           prc_plazas  \
# ...

# %% [markdown]
# ## `geonear()`
#
# Es una query de agregación. ¿Qué significa esto?
#
# La agregación en MongoDB sigue una estructura tipo *pipeline*, es decir,  diferentes etapas, donde cada una toma la salida de la anterior. Los elementos del *pipeline* se incluyen en un array y se ejecutarán por orden.
# Necesitaremos:
#
# - Unas coordenadas de referencia (en nuestro ejemplo geopoint). Recordamos que tienen que estar en formato de geopunto
#
#
# - Unos metros máximos o mínimos de distancia (en nuestro ejemplo metros)

# %%
query = [{
    "$geoNear": {'near': geopoint, # punto de referencia
                 'distanceField': 'distance', # el campo de salida que contiene la distancia calculada. 
                 'maxDistance': metros, # Opcional. Distancia en metros. La distancia máxima desde el punto central que pueden tener los documentos. 
                 'distanceMultiplier': 6371, # Opcional. El factor para multiplicar todas las distancias devueltas por la consulta. Por ejemplo, utilizamos el multiplicador de distancia para convertir los radianes, devueltos por una consulta esférica, en kilómetros multiplicándolos por el radio de la Tierra.
                 'spherical'  : True}}] # pra que tenga en cuenta que tiene que calcular las distancias en una esfera
geoloc = coleccion.aggregate(query)

# %%
df_geonear = pd.DataFrame(geoloc)

# %%
df_geonear.shape
# Out:
# (30, 27)

# %%
df_geonear.head()
# Out:
#                         _id  fid                             etiqueta  \
# 0  6203decac43d082d7be0f364  625           HOTEL BOUTIQUE CASA MOZART
# 1  6203decac43d082d7be0f1df  234  HOTEL SANTA CATALINA ROYAL HIDEAWAY
# 2  6203decac43d082d7be0f35a  615        HOTEL LAS PALMAS URBAN CENTER
# 3  6203decac43d082d7be0f36f  636         HOTEL SILKEN SAAJ LAS PALMAS
# 4  6203decac43d082d7be0f170  123                       HOTEL VALENCIA
#
#    granularidad cod_tipocat cod_tipo nom_tipo  cod_categor  nom_categor  \
# 0  ALOJAMIENTOS          H3  5510_L1    Hotel            3  3 Estrellas
# 1  ALOJAMIENTOS          H5  5510_L1    Hotel            5  5 Estrellas
# 2  ALOJAMIENTOS          H2  5510_L1    Hotel            2  2 Estrellas
# 3  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 4  ALOJAMIENTOS          H2  5510_L1    Hotel            2  2 Estrellas
#
#   gcd_isla      nom_isla gcd_entitur            nom_entitur gcd_nucltur  \
# ...

# %% [markdown]
# # Ploteemos los resultados

# %%
import folium

# %%
# crear mapa

mapa=folium.Map(location=[29.04824673674675, -13.604344913228068],  # la posicion
                tiles='openstreetmap',            # tipo de mapa, theme
                zoom_start=7)                    # zoom inicial

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for index, row in df_geometry.iterrows(): # método para iterar por los dataframes
    if row['cod_categor'] < 3:
    
        folium.Marker([row["latitud"], row['longitud']],
                      radius=10, 
                      tooltip = row['nom_categor'],
                      icon=folium.Icon(icon = "cloud", color = "red")).add_to(mapa)
    elif row['cod_categor']  == 3:
        folium.Marker([row["latitud"], row['longitud']],
                      radius=10, 
                      tooltip = row['nom_categor'],
                      icon=folium.Icon(icon = "cloud", color = "orange")).add_to(mapa)
    else:
        folium.Marker([row["latitud"], row['longitud']],
                      radius=10, 
                      tooltip = row['nom_categor'],
                      icon=folium.Icon(icon = "cloud", color = "green")).add_to(mapa)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## Guardar el mapa

# %%
# guardamos el mapa, solo lo podremos hacer en html

mapa.save(outfile= 'mapas/islas.html')
