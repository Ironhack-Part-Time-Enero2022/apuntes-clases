# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Contexto" data-toc-modified-id="Contexto-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Contexto</a></span></li><li><span><a href="#Leer-datos" data-toc-modified-id="Leer-datos-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Leer datos</a></span><ul class="toc-item"><li><span><a href="#Unir-todos-los-datasets" data-toc-modified-id="Unir-todos-los-datasets-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Unir todos los datasets</a></span></li></ul></li><li><span><a href="#Carga-en-Mongo" data-toc-modified-id="Carga-en-Mongo-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Carga en Mongo</a></span><ul class="toc-item"><li><span><a href="#Geoquery" data-toc-modified-id="Geoquery-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Geoquery</a></span></li></ul></li><li><span><a href="#Análisis-exploratorio-de-nuestros-datos:" data-toc-modified-id="Análisis-exploratorio-de-nuestros-datos:-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Análisis exploratorio de nuestros datos:</a></span></li><li><span><a href="#Transformación" data-toc-modified-id="Transformación-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Transformación</a></span><ul class="toc-item"><li><span><a href="#Columna-shopping-cart" data-toc-modified-id="Columna-shopping-cart-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Columna <code>shopping cart</code></a></span></li><li><span><a href="#Columna-de-latest_customer_review" data-toc-modified-id="Columna-de-latest_customer_review-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Columna de latest_customer_review</a></span></li><li><span><a href="#Columna-latest_customer_review" data-toc-modified-id="Columna-latest_customer_review-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Columna <code>latest_customer_review</code></a></span></li><li><span><a href="#Columna-season" data-toc-modified-id="Columna-season-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Columna <code>season</code></a></span></li><li><span><a href="#Columna-nearest_warehouse" data-toc-modified-id="Columna-nearest_warehouse-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Columna <code>nearest_warehouse</code></a></span></li></ul></li><li><span><a href="#Visualizacion" data-toc-modified-id="Visualizacion-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Visualizacion</a></span><ul class="toc-item"><li><span><a href="#Boxplot" data-toc-modified-id="Boxplot-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Boxplot</a></span></li><li><span><a href="#Scatterplot" data-toc-modified-id="Scatterplot-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Scatterplot</a></span></li><li><span><a href="#Barplot" data-toc-modified-id="Barplot-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Barplot</a></span></li><li><span><a href="#Mapas-con-folium" data-toc-modified-id="Mapas-con-folium-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Mapas con folium</a></span></li></ul></li></ul></div>

# %%
import pymongo
import numpy as np
import pandas as pd

# %% [markdown]
# # Contexto
# Este dataset contiene información sobre una tienda electrónica en línea. La tienda tiene tres almacenes desde los que se entregan los productos a los clientes.
#
# Columnas:
#
# - `order_id`: identificador único para cada pedido
#
#
# - `customer_id`: id único para cada cliente
#
#
# - `date`: La fecha en que se realizó el pedido, en formato AAAA-MM-DD
#
#
#
# - `nearest_warehouse`: el nombre del almacén más cercano al cliente
#
#
#
# - `shopping_cart`: lista de tuplas que representan los artículos del pedido: el primer elemento de el primer elemento de la tupla es el artículo pedido, y el segundo elemento es la cantidad pedida para dicho artículo.
#
#
#
# - `order_price`: precio del pedido en USD. El precio del pedido es el precio de los artículos antes de que se apliquen descuentos.
#
#
# - `delivery_charges`: los gastos de envío del pedido
#
#
# - `customer_lat`: latitud de la ubicación del cliente
#
#
# - `customer_long`: longitud de la ubicación del cliente
#
#
# - `coupon_discount`: el porcentaje de descuento que se aplicará al el precio del pedido.
#
#
# - `order_total`: total del pedido en USD después de aplicar todos los descuentos y/o gastos de envío.
#
#
# - `season`: la época en la que se realizó el pedido.
#
#
# - `is_expedited_delivery`: indica si el cliente ha solicitado una entrega rápida
#
#
# - `distance_to_nestest_warehouse`: la distancia en kilómetros, entre el cliente y el almacén más cercano a él.
#
#
# - `latest_customer_review`: la última opinión del cliente sobre su pedido más reciente
#
#
# - `is_happy_customer`: indica si el cliente es un cliente feliz o tuvo un problema con su último pedido.

# %% [markdown]
# # Leer datos

# %%
df1 = pd.read_csv("../data/report_1.csv", index_col = 0)
df2 = pd.read_csv("../data/report_2.csv", index_col = 0)
df3 = pd.read_csv("../data/report_3.csv", index_col = 0)

# %%
df1.head(2)
# Out:
#     order_id   customer_id        date nearest_warehouse  \
# 0  ORD182494  ID6197211592  2019-06-22          Thompson
# 1  ORD395518  ID0282825849  2019-12-29          Thompson
#
#                                        shopping_cart  order_price  \
# 0  [('Lucent 330S', 1), ('Thunder line', 2), ('iS...        12200
# 1        [('Thunder line', 1), ('Universe Note', 2)]         9080
#
#    delivery_charges  customer_lat  customer_long  coupon_discount  \
# 0             79.89    -37.815105     144.932843               10
# 1             62.71    -37.802736     144.951118                0
#
#    order_total  season  is_expedited_delivery  distance_to_nearest_warehouse  \
# 0     11059.89  Winter                   True                         1.2800
# 1      9142.71  Summer                  False                         1.1621
#
#                               latest_customer_review  is_happy_customer
# 0  perfect phone and trusted seller. phone itself...               True
# ...

# %%
df2.head(2)
# Out:
#       order_id   customer_id        date nearest_warehouse  \
# 338  ORD108392  ID2069604238  2019-09-21         nickolson
# 339  ORD127881  ID2776664746  2019-09-23          Thompson
#
#                                          shopping_cart  order_price  \
# 338  [('Olivia x460', 1), ('Lucent 330S', 2), ('iAs...         5910
# 339  [('Candle Inferno', 1), ('Toshika 750', 1), ('...         7360
#
#      delivery_charges  customer_lat  customer_long  coupon_discount  \
# 338            108.54    -37.802492     144.980952                5
# 339            107.35    -37.826394     145.019418               25
#
#      order_total  season  is_expedited_delivery  \
# 338      5723.04  Spring                   True
# 339      5627.35  Spring                   True
#
#      distance_to_nearest_warehouse           latest_customer_review  \
# 338                         1.5083               four stars big fan
# 339                         1.5854  good phone very good condition.
#
# ...

# %%
df3.head(2)
# Out:
#       order_id   customer_id        date nearest_warehouse  \
# 165  ORD153030  ID0310729984  2019-05-02          Thompson
# 166  ORD234851  ID0547586405  2019-06-25            Bakers
#
#                                          shopping_cart  order_price  \
# 165  [('Olivia x460', 2), ('pearTV', 1), ('Universe...        15660
# 166                [('Lucent 330S', 2), ('pearTV', 1)]         8770
#
#      delivery_charges  customer_lat  customer_long  coupon_discount  \
# 165             78.02    -37.812726     144.940215               10
# 166             65.06    -37.813517     144.985586               15
#
#      order_total  season  is_expedited_delivery  \
# 165     14172.02  Autumn                   True
# 166      7519.56  Winter                  False
#
#      distance_to_nearest_warehouse  \
# 165                         0.6028
# 166                         0.9345
#
#                                 latest_customer_review  is_happy_customer
# ...

# %% [markdown]
# ## Unir todos los datasets

# %%
df = pd.concat([df1,df2,df3], axis = 0)

# %%
df.head(2)
# Out:
#     order_id   customer_id        date nearest_warehouse  \
# 0  ORD182494  ID6197211592  2019-06-22          Thompson
# 1  ORD395518  ID0282825849  2019-12-29          Thompson
#
#                                        shopping_cart  order_price  \
# 0  [('Lucent 330S', 1), ('Thunder line', 2), ('iS...        12200
# 1        [('Thunder line', 1), ('Universe Note', 2)]         9080
#
#    delivery_charges  customer_lat  customer_long  coupon_discount  \
# 0             79.89    -37.815105     144.932843               10
# 1             62.71    -37.802736     144.951118                0
#
#    order_total  season  is_expedited_delivery  distance_to_nearest_warehouse  \
# 0     11059.89  Winter                   True                         1.2800
# 1      9142.71  Summer                  False                         1.1621
#
#                               latest_customer_review  is_happy_customer
# 0  perfect phone and trusted seller. phone itself...               True
# ...

# %%
df.shape
# Out:
# (658, 16)

# %%
df.dtypes
# Out:
# order_id                          object
# customer_id                       object
# date                              object
# nearest_warehouse                 object
# shopping_cart                     object
# order_price                        int64
# delivery_charges                 float64
# customer_lat                     float64
# customer_long                    float64
# coupon_discount                    int64
# order_total                      float64
# season                            object
# is_expedited_delivery               bool
# distance_to_nearest_warehouse    float64
# latest_customer_review            object
# is_happy_customer                   bool
# geometria                         object
# dtype: object

# %% [markdown]
# # Carga en Mongo

# %%
# creamos la función para convertir nuestras coordenadas a geopuntos para poder hacer geoqueries


def crear_geometria(lon,lat):
    '''
    Función que convierte nuestras coordenadas de lat y long en un geopunto
    Args:
        lon: float con la longitud de cada uno de los clientes
        lat: floar con la latitud de cada uno de los clientes
    Returns: 
        Un diccionario con nuestras coordenadas convertidas a geopuntos
    '''
    return {"type": "Point", "coordinates":[ lon, lat]}

# %%
#aplicamos nuestra función

df["geometria"] = df.apply(lambda datos: crear_geometria(
                                    datos["customer_long"],
                                    datos["customer_lat"]), axis = 1)

# %%
df.head(2)
# Out:
#     order_id   customer_id        date nearest_warehouse  \
# 0  ORD182494  ID6197211592  2019-06-22          Thompson
# 1  ORD395518  ID0282825849  2019-12-29          Thompson
#
#                                        shopping_cart  order_price  \
# 0  [('Lucent 330S', 1), ('Thunder line', 2), ('iS...        12200
# 1        [('Thunder line', 1), ('Universe Note', 2)]         9080
#
#    delivery_charges  customer_lat  customer_long  coupon_discount  \
# 0             79.89    -37.815105     144.932843               10
# 1             62.71    -37.802736     144.951118                0
#
#    order_total  season  is_expedited_delivery  distance_to_nearest_warehouse  \
# 0     11059.89  Winter                   True                         1.2800
# 1      9142.71  Summer                  False                         1.1621
#
#                               latest_customer_review  is_happy_customer  \
# 0  perfect phone and trusted seller. phone itself...               True
# ...

# %%
# creamos la conexión con Mongo Compass
client = pymongo.MongoClient()

# %%
# creamos bbdd
db = client.electronic

# %%
# creamos coleccion

coleccion = db.sales

# %%
# insertamos nuestro dataset en Mongo

coleccion.insert_many(df.to_dict("records"))

# %%
# haremos geoqueriesm por lo que necesitamos crear el índice

coleccion.create_index([('geometria', '2dsphere')])
# Out:
# 'geometria_2dsphere'

# %% [markdown]
# ## Geoquery

# %%
# definimos el punto de referencia y la distancia máxima que queremos. 

geopoint = {'type': 'Point', 'coordinates':[144.96787921592158, -37.82385677492879]}
metros = 2000

# %%
# hacemos la geoquery

busqueda = coleccion.find({'geometria':{
        '$near': {'$geometry': geopoint, '$maxDistance':metros}
    }})
busqueda

# %%
# almacenamos los resultados en un dataframe

resultado_near = pd.DataFrame(busqueda)

# %%
resultado_near.head()
# Out:
#                         _id   order_id   customer_id        date  \
# 0  6207771e6828d639036be697  ORD037011  ID0847526574  2019-11-11
# 1  6207771e6828d639036be52f  ORD371930  ID6231506306  2019-06-29
# 2  6207771e6828d639036be54d  ORD228614  ID0298045612  2019-10-10
# 3  6207771e6828d639036be696  ORD366469  ID0846567658  2019-01-28
# 4  6207771e6828d639036be642  ORD246022  ID0662736521  2019-12-19
#
#   nearest_warehouse                                      shopping_cart  \
# 0         Nickolson  [('iStream', 2), ('Olivia x460', 1), ('Toshika...
# 1         Nickolson              [('Alcon 10', 2), ('Toshika 750', 2)]
# 2         Nickolson  [('Alcon 10', 2), ('Lucent 330S', 1), ('iAssis...
# 3         Nickolson         [('Universe Note', 1), ('Lucent 330S', 2)]
# 4         Nickolson  [('Universe Note', 1), ('Lucent 330S', 1), ('A...
#
#    order_price  delivery_charges  customer_lat  customer_long  \
# 0        18465            102.31    -37.823506     144.967576
# ...

# %%
resultado_near.to_csv('../data/resultado_query.csv')
