# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#¿Qué-son-las-funciones?" data-toc-modified-id="¿Qué-son-las-funciones?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>¿Qué son las funciones?</a></span><ul class="toc-item"><li><span><a href="#Built-in-Functions" data-toc-modified-id="Built-in-Functions-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Built-in Functions</a></span></li><li><span><a href="#Motivación" data-toc-modified-id="Motivación-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Motivación</a></span></li></ul></li><li><span><a href="#Sintáxis-básica" data-toc-modified-id="Sintáxis-básica-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Sintáxis básica</a></span><ul class="toc-item"><li><span><a href="#Argumentos-vs-Parámetros" data-toc-modified-id="Argumentos-vs-Parámetros-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Argumentos <em>vs</em> Parámetros</a></span></li><li><span><a href="#Variables-locales-vs-globales" data-toc-modified-id="Variables-locales-vs-globales-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Variables locales <em>vs</em> globales</a></span><ul class="toc-item"><li><span><a href="#Variables-locales" data-toc-modified-id="Variables-locales-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Variables locales</a></span></li></ul></li><li><span><a href="#Variables-globales" data-toc-modified-id="Variables-globales-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Variables globales</a></span></li><li><span><a href="#Funciones-con-parámetros" data-toc-modified-id="Funciones-con-parámetros-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Funciones con parámetros</a></span></li><li><span><a href="#Funciones-sin-parámetros" data-toc-modified-id="Funciones-sin-parámetros-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Funciones sin parámetros</a></span></li><li><span><a href="#Funciones-que-devuelven-varios-elementos" data-toc-modified-id="Funciones-que-devuelven-varios-elementos-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Funciones que devuelven varios elementos</a></span></li><li><span><a href="#Funciones-sin-return" data-toc-modified-id="Funciones-sin-return-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Funciones sin <em>return</em></a></span></li></ul></li><li><span><a href="#Documentación-de-las-funciones-(docstrings)" data-toc-modified-id="Documentación-de-las-funciones-(docstrings)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Documentación de las funciones (<em>docstrings</em>)</a></span></li><li><span><a href="#Parámetros-por-defecto" data-toc-modified-id="Parámetros-por-defecto-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Parámetros por defecto</a></span></li><li><span><a href="#args-y-kwargs" data-toc-modified-id="args-y-kwargs-5"><span class="toc-item-num">5&nbsp;&nbsp;</span><em>args</em> y <em>kwargs</em></a></span><ul class="toc-item"><li><span><a href="#*args" data-toc-modified-id="*args-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>*args</a></span></li><li><span><a href="#**kwargs" data-toc-modified-id="**kwargs-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>**kwargs</a></span></li></ul></li><li><span><a href="#Recursividad" data-toc-modified-id="Recursividad-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Recursividad</a></span></li></ul></div>

# %% [markdown]
# ![functions_portada.png](attachment:functions_portada.png)

# %% [markdown]
# # ¿Qué son las funciones?

# %% [markdown]
# Vuestras aportaciones 👇🏽:

# %% [markdown]
# - Estructuras de código que nos ayudan a no repetir nuestro código
# - Un programa dentro de un programa
# - Requiere argumentos o no
# - Tienen que tener un return
# - Se puede gráficar, son universales

# %% [markdown]
# Una función es un bloque de código que encapsula una tarea específica o grupo de tareas relacionadas.
#
# Las funciones ayudan a dividir nuestro código en trozos más pequeños y modulares. A medida que nuestro código se hace más grande, las funciones lo hacen más organizado y manejable.
#
# Además, evitan la repetición y hacen que el código sea reutilizable.

# %% [markdown]
# ## Built-in Functions

# %% [markdown]
# **Hasta ahora ya hemos estado trabajando con algunas funciones de Python**, ya que tiene una serie de funciones ya incorporadas, son las llamadas `Built-in Functions`
#
#
# [Aquí](https://docs.python.org/3/library/functions.html) este tipo de funciones ya definidas en Python

# %%
len("hola")
# Out:
# 4

# %%
print('hola mundo, que tal estas?')
# Out:
# hola mundo, que tal estas?

# %%
max([1,2,3,4,5,6,6,7,77,78])
# Out:
# 78

# %%
type(len)
# Out:
# builtin_function_or_method

# %% [markdown]
# Si tenéis más curiosidad sobre el código fuente de estas funciones, podeís encontrarlo en [este](https://github.com/python/cpython/blob/main/Python/bltinmodule.c) repo de GitHub
#
#
# 👇🏽 Y tiene un aspecto como esto de aquí 👇🏽
#
# ```python
# builtin_sorted(PyObject *self, PyObject *const *args, Py_ssize_t nargs, PyObject *kwnames)
# {
#     PyObject *newlist, *v, *seq, *callable;
#
#     /* Keyword arguments are passed through list.sort() which will check
#        them. */
#     if (!_PyArg_UnpackStack(args, nargs, "sorted", 1, 1, &seq))
#         return NULL;
#
#     newlist = PySequence_List(seq);
#     if (newlist == NULL)
#         return NULL;
#
#     callable = _PyObject_GetAttrId(newlist, &PyId_sort);
#     if (callable == NULL) {
#         Py_DECREF(newlist);
#         return NULL;
#     }
#
#     assert(nargs >= 1);
#     v = _PyObject_FastCallKeywords(callable, args + 1, nargs - 1, kwnames);
#     Py_DECREF(callable);
#     if (v == NULL) {
#         Py_DECREF(newlist);
#         return NULL;
#     }
#     Py_DECREF(v);
#     return newlist;
# }
#
# ```

# %% [markdown]
# ##  Motivación

# %% [markdown]
# - `Reutilización`: supongamos que escribimos un código que es muy útil para nuestro objetivo, y según avanzamos en nuestro trabajo vemos que lo vamos a necesitar en varias ocasiones. En este caso podemos copiar y pegar una y otra vez el código, pero esto puede resultar algo tedioso si lo tenemos que hacer muchas veces.
#
#     Imaginemos ahora que hemos encontrado un error en nuestro código, tendríamos que ir uno a uno cambiándolo, lo que podría llevar a que se nos olvidará en alguna de las copias o nos equivoquemos.
#
#     La solución para esto, crear una función que realice la tarea que queremos repetir.
#
#
#
# - `Modularidad`: las funciones permiten dividir procesos en pasos más pequeños.
#
#     Imaginemos que tenemos un código que lee un archivo, procesa el contenido y escribe un archivo de salida. Nosotros nos podremos crear tres funciones, una para cada tarea que sea universal para este archivo pero también para cualquier otro.

# %% [markdown]
# # Sintáxis básica

# %% [markdown]
# ![estr_funciones.svg](attachment:estr_funciones.svg)

# %% [markdown]
# Cuando trabajamos con funciones debemos tener en cuenta:
#
#
# - El orden de los parámetros es importante.
#
#
# - Sólo debe haber un valor para un parámetro.

# %% [markdown]
# ## Argumentos *vs* Parámetros

# %% [markdown]
# En la definición de una función los valores que se reciben se denominan **parámetros**, pero durante la llamada los valores que se envían se denominan **argumentos**.

# %% [markdown]
# ```python
# def resta(a, b):
#     return a - b
#
# resta(30, 10)  # argumento 30 => parámetro a
#                # argumento 10 => parámetro b
# ```

# %% [markdown]
# ## Variables locales *vs* globales

# %% [markdown]
# Las variables globales son aquellas que no están definidas dentro de ninguna función y tienen un alcance global, mientras que las variables locales son aquellas que están definidas dentro de una función y su alcance está limitado sólo a esa función.
#
# En otras palabras, podemos decir que las variables locales son accesibles sólo dentro de la función en la que se inicializó mientras que las variables globales son accesibles en todo el programa y dentro de cada función.

# %% [markdown]
# ### Variables locales

# %% [markdown]
# Las variables locales son aquellas que se inicializan dentro de una función y pertenecen sólo a esa función en particular. No se puede acceder a ellas fuera de la función.

# %%
def mi_funcion():
    
    #variable local
    verdad = "Me gusta Python"
    return verdad

# %%
# si definimos una función sin parámetros pero le pasamos uno, nos dará error! 
# el error nos dice, la función recibe un parámetro cuando hemos especificado 
# que no debería recibir ninguno
mi_funcion("Hola")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-07372a7a5807> in <module>
# ----> 1 mi_funcion("Hola")
#
# TypeError: mi_funcion() takes 0 positional arguments but 1 was given

# %%
mi_funcion()
# Out:
# 'Me gusta Python'

# %%
# verdad esta definida dentro de la función (de la isla) fuera de ella para Python no existe
verdad
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9bf857beea0f> in <module>
# ----> 1 verdad
#
# NameError: name 'verdad' is not defined

# %% [markdown]
# ## Variables globales

# %% [markdown]
# Las variables globales son aquellas que se definen fuera de cualquier función y que son accesibles en todo el programa, es decir, dentro y fuera de cada función.

# %%
la_verdad = 'Python es el mejor lenguaje de programación'

# %%
def mi_funcion2():
    print(f' Dentro de la funcion:  {la_verdad}')

# %%
mi_funcion2()
# Out:
#  Dentro de la funcion:  Python es el mejor lenguaje de programaciónPython es el mejor lenguaje de programación

# %%
print(f'Fuera de la función: {la_verdad}')
# Out:
# Fuera de la función: Python es el mejor lenguaje de programaciónPython es el mejor lenguaje de programación

# %%
def mi_funcion3(a):
    a = a * 2
    return a

# %%
mi_funcion3(la_verdad)
# Out:
# 'Python es el mejor lenguaje de programaciónPython es el mejor lenguaje de programaciónPython es el mejor lenguaje de programaciónPython es el mejor lenguaje de programación'

# %%
for name in ["alicia", "antonio"]:
    print(name.upper())
# Out:
# ALICIA
# ANTONIO

# %%
chorizo = 25
mi_funcion3(chorizo)
# Out:
# 50

# %%
chorizo = mi_funcion3(25)

# %%
chorizo
# Out:
# 50

# %%
la_verdad = mi_funcion3(la_verdad)

# %%
la_verdad
# Out:
# 'Python es el mejor lenguaje de programaciónPython es el mejor lenguaje de programaciónPython es el mejor lenguaje de programaciónPython es el mejor lenguaje de programación'

# %%
def mi_funcion3():
    la_verdad = "Hola"
    
    return la_verdad

# %%
lst = [1,2,3,4]

def multiplicacion(lista):
    mult = []
    for i in lista:
        mult.append(i * 2)
    return mult

# %%
multiplicacion(lst)
# Out:
# [2, 4, 6, 8]

# %%
lst
# Out:
# [1, 2, 3, 4]

# %%
lst = multiplicacion(lst)

# %%
lst
# Out:
# [2, 4, 6, 8]

# %%
multiplicacion(lst)
# Out:
# [4, 8, 12, 16]

# %% [markdown]
# ## Funciones con parámetros

# %% [markdown]
# Imaginemos que queremos calcular la tabla de multiplicar de un número dado:

# %%
num = 2

# %%
print(num, 'x 1 = ', num * 1)
print(num, 'x 2 = ', num * 2)
print(num, 'x 3 = ', num * 3)
print(num, 'x 4 = ', num * 4)
print(num, 'x 5 = ', num * 5)
print(num, 'x 6 = ', num * 6)
print(num, 'x 7 = ', num * 7)
print(num, 'x 8 = ', num * 8)
print(num, 'x 9 = ', num * 9)
# Out:
# 2 x 1 =  2
# 2 x 2 =  4
# 2 x 3 =  6
# 2 x 4 =  8
# 2 x 5 =  10
# 2 x 6 =  12
# 2 x 7 =  14
# 2 x 8 =  16
# 2 x 9 =  18

# %%
num2 = 3

# %%
print(num2, 'x 1 = ', num2 * 1)
print(num2, 'x 2 = ', num2 * 2)
print(num2, 'x 3 = ', num2 * 3)
print(num2, 'x 4 = ', num2 * 4)
print(num2, 'x 5 = ', num2 * 5)
print(num2, 'x 6 = ', num2 * 6)
print(num2, 'x 7 = ', num2 * 7)
print(num2, 'x 8 = ', num2 * 8)
print(num2, 'x 9 = ', num2 * 9)
# Out:
# 3 x 1 =  3
# 3 x 2 =  6
# 3 x 3 =  9
# 3 x 4 =  12
# 3 x 5 =  15
# 3 x 6 =  18
# 3 x 7 =  21
# 3 x 8 =  24
# 3 x 9 =  27

# %%
def multi(num):
    tabla = []
    for i in range(0, 10):
        tabla.append(num * i)
    return tabla

# %%
# tabla solo esta definido dentro de la función (es una variable local), 
## por lo tanto, cuando intentamos acceder a ella fuera de la función 
### nos dice que no está definida

tabla
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-273-6fb19f2b33c9> in <module>
#       3 ### nos dice que no está definida
#       4
# ----> 5 tabla
#
# NameError: name 'tabla' is not defined

# %%
def multi(num):
    tabla = []
    for i in range(1,10):
        res = num * i
        valor = str(num) + 'x' + str(i) + '=' + str(res)
        tabla.append(valor)
    return tabla

# %%
# ojo, todo lo que pertenezca a la función tiene que estar indentado hacia la derecha! 
def multi2(num):
tabla = []
for i in range(0, 10):
    tabla.append(num * i)
    print(num * i)
    return tabla
# Out:
#   File "<ipython-input-75-32b20daf8a84>", line 2
#     tabla = []
#     ^
# IndentationError: expected an indented block

# %%
def multi5(num):
    tabla = []
    for i in range(0, 10):
        tabla.append(num * i)
        print(f'estamos multiplicando {i}')
    return tabla

# %%
tabla_7 = multi5(7)
tabla_7
# Out:
# estamos multiplicando 0
# estamos multiplicando 1
# estamos multiplicando 2
# estamos multiplicando 3
# estamos multiplicando 4
# estamos multiplicando 5
# estamos multiplicando 6
# estamos multiplicando 7
# estamos multiplicando 8
# estamos multiplicando 9
# [0, 7, 14, 21, 28, 35, 42, 49, 56, 63]

# %%
tabla3 = multi(3)
tabla3
# Out:
# ['3x1=3',
#  '3x2=6',
#  '3x3=9',
#  '3x4=12',
#  '3x5=15',
#  '3x6=18',
#  '3x7=21',
#  '3x8=24',
#  '3x9=27']

# %%
tabla4 = multi(4)
tabla4
# Out:
# ['4x1=4',
#  '4x2=8',
#  '4x3=12',
#  '4x4=16',
#  '4x5=20',
#  '4x6=24',
#  '4x7=28',
#  '4x8=32',
#  '4x9=36']

# %%
def saludo(nombre):
    if len(nombre) > 4:
        print("el nombre es largo")
        return "Bienvenido"
    else:
        print("el nombre es corto")
        return "no te queremos aqui"

# %%
saludo("Rodrigo")
# Out:
# el nombre es largo
# 'Bienvenido'

# %%
rodri = saludo("Rodrigo")
# Out:
# el nombre es largo

# %%
rodri
# Out:
# 'Bienvenido'

# %%
# si le pasamos Rodrigo sin ser srting lo entenderá como una variable
## pero nosotros no hemos definido ninguna variable que se llame Rodrigo
### por lo que nos dará error 👇🏽
saludo(Rodrigo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-284-79b0d5c7a8fd> in <module>
# ----> 1 saludo(Rodrigo)
#
# NameError: name 'Rodrigo' is not defined

# %%
# la función saludo esta creada para trabajar con srtings
## Si le pasamos un número nos dará error porque estamos intentando
### aplicar un metodo de string en un número. IMPOSIBLE!
saludo(9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-285-cb2ef00acf53> in <module>
# ----> 1 saludo(9)
#
# <ipython-input-280-210b9d056978> in saludo(nombre)
#       1 def saludo(nombre):
# ----> 2     if len(nombre) > 4:
#       3         print("el nombre es largo")
#       4         return "Bienvenido"
#       5     else:
#
# TypeError: object of type 'int' has no len()

# %%
saludo("ana")
# Out:
# el nombre es corto
# 'no te queremos aqui'

# %% [markdown]
# Imaginemos que tenemos dos alumnos en una clase, y queremos calcular la media de sus notas

# %%
alumno_1 = 9
alumno_2 = 7

# %%
suma = alumno_1 + alumno_2
suma
# Out:
# 16

# %%
media = suma / 2
media
# Out:
# 8.0

# %%
def media (a, b):
    suma = a + b
    media = suma/2
    return media

# %%
media(4,7)
# Out:
# 5.5

# %%
media (8, 2)
# Out:
# 5.0

# %%
media(alumno_1, alumno_2)
# Out:
# 8.0

# %%
# podemos almacenar el resultado de nuestra función en una variable
numero = media(2,7)

# %% [markdown]
# Pero esto es poco práctico, porque estamos creando una función muy específica para una clase con dos alumnos.
#
# 🤔 ¿Cómo podríamos hacer esto para que sea más "universal", para que nos sirva para cualquier clase, independientemente del número de alumnos que tengamos?
#
# A una función le podemos pasar cualquier tipo de dato o estructura de datos (*integers*, *floats*, listas, diccionarios etc.)

# %%
lista_notas = [6,8,9,6,7,8]

# %%
sum(lista_notas)
# Out:
# 44

# %%
# si en vez de pasarle las notas por separado le pasamos una lista:
def media2(x):
    suma = sum(x)
    total = len(x)
    return suma/total

# %%
media2(lista_notas)
# Out:
# 7.333333333333333

# %%
lista_notas2 = [5,6,7,8,9,4,5,2,6,7,9,4,2,6,7]

# %%
media2(lista_notas2)
# Out:
# 5.8

# %% [markdown]
# **EJERCICIO** Escribe una función que le pasemos un *string* y nos devuelva ese *string* en mayúsculas

# %%
frase = "Buenos dias"

# %%
def mayus(x):
    return x.upper()

# %%
mayus(frase)
# Out:
# 'BUENOS DIAS'

# %%
frase_mayuscula = mayus(frase)

# %%
frase_mayuscula
# Out:
# 'BUENOS DIAS'

# %% [markdown]
# **EJERCICIO** Escribir una función que reciba una lista y nos quite los elementos repetidos

# %%
lst = [1,1,2,3,4,45,45,67,89,89]

# %%
def no_duplicados(jamon):
    return set(jamon)

# %%
no_duplicados(lst)
# Out:
# {2, 4, 6, 8}

# %%
# otra forma de hacerlo
def no_duplicados2(lista):
    no_repetidos = []
    for i in lista:
        if i not in no_repetidos:
            no_repetidos.append(i)
    return no_repetidos

# %%
no_duplicados2(lst)
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# **EJERCICIO** escribir una función que nos devuelva los elementos que NO se repiten en la lista

# %%
lst.count(1)
# Out:
# 2

# %%
def no_duplicados2(jamon):
    unicos = []
    for i in jamon:
        if jamon.count(i) == 1:
            unicos.append(i)
    return unicos

# %%
no_duplicados2(lst)
# Out:
# [2, 3, 4, 67]

# %% [markdown]
# ## Funciones sin parámetros

# %%
from datetime import datetime

# %%
now = datetime.today()
now
# Out:
# datetime.datetime(2022, 1, 22, 11, 12, 10, 133162)

# %%
def hoy():
    return datetime.today()

# %%
now = hoy()

# %%
now
# Out:
# datetime.datetime(2022, 1, 22, 11, 14, 23, 825276)

# %%
type(hoy())
# Out:
# datetime.datetime

# %%
# hemos definido la funcion hoy para que no reciba parámetros.
## si le pasaramos uno porque estamos despistados nos dará error!
now = hoy(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-c135605d3284> in <module>
# ----> 1 now = hoy(4)
#
# TypeError: hoy() takes 0 positional arguments but 1 was given

# %%
# Weekday as locale’s full name.
now.strftime("%A")
# Out:
# 'Saturday'

# %%
# Month as locale’s full name.
now.strftime("%B")
# Out:
# 'January'

# %% [markdown]
# [Documentacion](https://docs.python.org/3/library/datetime.html#strftime-strptime-behavior) interesante sobre el formateo de las letras

# %% [markdown]
# ## Funciones que devuelven varios elementos

# %%
def desguazar (num1, num2):
    resultado = num1 // num2
    resto = num1 % num2
    return resultado, resto

# %%
 # nos lo devuelve en formato de tupla!
desguazar(23,5)
# Out:
# (4, 3)

# %%
type(desguazar(23,5))
# Out:
# tuple

# %%
# vale, pero como almaceno esos resultados en una variable
jamo, brocoli = desguazar(23,5)

# %%
z = [1,2], [1,3]

# %%
type(z)
# Out:
# tuple

# %%
x, y = [1,2], [1,3]

# %%
x
# Out:
# [1, 2]

# %%
y
# Out:
# [1, 3]

# %%
jamo
# Out:
# 4

# %%
type(jamo)
# Out:
# int

# %%
brocoli
# Out:
# 3

# %%
resultado = desguazar(23, 9)[0]

# %%
res = desguazar(23, 9)[1]

# %%
res
# Out:
# 5

# %% [markdown]
# ## Funciones sin *return*

# %% [markdown]
# **¿Qué pasa si a una función no le ponemos return?** 🤔
#
# > Una función sin return nos va devuelve **None**

# %%
def numero_maximo(a, b):
    if a > b:
        maximo = a
    else:
        maximo = b

# %%
numero_maximo(2,3)

# %%
type(numero_maximo(2,3))
# Out:
# NoneType

# %% [markdown]
# 📌 No confundir `print` con `return`!!!!
#
# - `print()`: sirve para mostrar un mensaje en pantalla.
#
#
# - `return`: se utiliza para establecer el resultado (o valor de retorno) de una función.

# %%
def numero_maximo(a, b):
    if a > b:
        maximo = a
        print('el maximo es', maximo, 'el primer argumento')
    else:
        maximo = b
        print('el maximo es', maximo, 'el segundo argumento')

# %%
v = numero_maximo(2,3)
v
# Out:
# el maximo es 3 el segundo argumento

# %%
v # no nos devuelve nada... NO HAY RETURN!!!

# %%
def numero_maximo(a, b):
    if a > b:
        maximo = a
    else:
        maximo = b
        
    return maximo

# %%
b = numero_maximo(6, 8)

# %%
b
# Out:
# 8

# %%
type(b)
# Out:
# int

# %% [markdown]
# # Documentación de las funciones (*docstrings*)

# %% [markdown]
# > El código se lee más a menudo que se escribe.
#
# > Ayuda a nuestros compañeros y a nosotros mismos a entender el código.

# %% [markdown]
# ```python
# def suma(parametro1, parametro2):
#     """
#     Lo que hace la función
#     Args: (los parámetros que recibe)
#         parametro1 (tipo): que es
#         parámetro2 (tipo): que es
#     Returns:
#         Lo que nos devuelve la función
#     """
#     return parametro1 + parametro2
# ````

# %%
def cuadrado (x):
    '''
    Calcula el cuadrado de un número que le pasemos
    Args:
        x (int, float): el número que elevamos al cuadrado
    Returns:
        nos devuelve el parámetro elevado al cuadrado
    '''
    return x ** 2

# %%
print(cuadrado.__doc__)
# Out:
#     Calcula el cuadrado de un número que le pasemos
#     Args:
#         x (int, float): el número que elevamos al cuadrado
#     Returns:
#         nos devuelve el parámetro elevado al cuadrado

# %% [markdown]
# # Parámetros por defecto

# %% [markdown]
# Los argumentos por defecto indican que el argumento de la función tomará ese valor si no se pasa otro valor cuando llamamemos a la función.
#
# El valor por defecto se asigna mediante el operador de asignación(=) de la forma nombre de la `clave=valor`.

# %% [markdown]
# Imaginemos que queremos hacer una función de saludo. La función recibirá dos parámetros:
#
# - El nombre de la persona a la que queremos saludar
#
#
# - El saludo de buenos dias, que será igual siempre (este será nuestro argumento por defecto)

# %%
def buenos_dias (nombre, saludo = "buenos dias 🙂"):
    frase = f'Hola {nombre} {saludo}'
    return frase

# %%
buenos_dias("Alicia")
# Out:
# 'Hola Alicia buenos dias 🙂'

# %%
buenos_dias( "Alicia","estoy muy cansada")
# Out:
# 'Hola Alicia estoy muy cansada'

# %%
def calculadora(num1,num2, operacion = "multiplicacion"):
    if operacion == "multiplicacion":
        return num1 * num2
    elif operacion == "suma":
        return num1 + num2
    elif operacion == "resta":
        return num1 -num2

# %%
calculadora(2,3)
# Out:
# 6

# %%
calculadora(2,3, "suma")
# Out:
# 5

# %%
calculadora(2,3, "resta")
# Out:
# -1

# %%
operacion = "multiplicacion"

# %%
def calculadora2(num1,num2, operacion):
    if operacion == "multiplicacion":
        return num1 * num2
    elif operacion == "suma":
        return num1 + num2
    elif operacion == "resta":
        return num1 -num2

# %%
calculadora2(2,3) # si ponemos operación como un parámetro mas pero lo especificamos cuando llamamos a la funcion por mucho que este definido fuera de la funcion nos dara eroor!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-189-368b1f09d161> in <module>
# ----> 1 calculadora(2,3)
#
# TypeError: calculadora() missing 1 required positional argument: 'operacion'

# %% [markdown]
# # *args* y *kwargs*

# %% [markdown]
# El principal uso de `*args` y `**kwargs` es en la definición de funciones.
#
# Ambos permiten pasar un número variable de argumentos a una función, por lo que si quieres definir una función cuyo número de parámetros de entrada puede ser variable, considera el uso de `*args` o `**kwargs` como un argumento.

# %% [markdown]
# ## *args

# %% [markdown]
# Es una lista de argumentos, como argumentos posicionales.

# %%
# definimos una función que nos sume tres números
def suma(a,b,c):
    return a + b + c

# %%
suma(1,2,3)
# Out:
# 6

# %% [markdown]
# Pero que pasa si queremos sumar más números?

# %%
suma(1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-192-8b8c80de2337> in <module>
# ----> 1 suma(1,2,3,4)
#
# TypeError: suma() takes 3 positional arguments but 4 were given

# %%
lista_numeros = [1,2,3,4,5,6,7]

# %%
def suma2 (*args):
    print(type(args))
    suma = 0
    for i in num:
        suma += i
    return suma

# %%
suma2(1,2,3,4,5,6,7)
# Out:
# <class 'tuple'>
# 28

# %%
suma2(1,2)
# Out:
# <class 'tuple'>
# 3

# %%
suma2(*lista_numeros)
# Out:
# <class 'tuple'>
# 28

# %%
def suma3 (lista_):
    suma = 0
    for i in lista_:
        suma += i
    return suma

# %%
for i in range(len(lista_numeros)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
lista_numeros = [1,2,3,4,5,6,7, 56]

# %%
suma3(lista_numeros)
# Out:
# 84

# %%
def restaurantes(*ciudad):
    pasan cosas

# %%
restaurantes("madrid", "Roma", "Paris")

# %%
# la alternativa si queremos sacar mas dinerito 🤑

lista_ciudades = ["madrid", "roma", "paris"]

def restaurantes2(lista_ciudades):
    pasan cosas

# %% [markdown]
# ## **kwargs

# %%
diccionario = {'brocoli': 1.50, 
              'chorizo': 4.5, 
              'zanahoria': 1.30, 
              'jamon': 7.90}

# %%
def precio (**kwargs):
    for k,v in kwargs.items():
        
        print(k, "---->", v)

# %%
def precio2 (**kwargs):
    for k,v in kwargs.items():
        if k == "chorizo":
            print(k, "---->", v)

# %%
precio(**diccionario)
# Out:
# brocoli ----> 1.5
# chorizo ----> 4.5
# zanahoria ----> 1.3
# jamon ----> 7.9

# %%
precio2(**diccionario)
# Out:
# chorizo ----> 4.5

# %% [markdown]
# **SI JUNTAMOS ARGS CON KWARGS**
#
# ⚠️ El orden importa!!!! ⚠️
#
# ```python
# def (*args, **kwargs):
# ```

# %%
diccionario = {'brocoli': 1.50, 
              'chorizo': 4.5, 
              'zanahoria': 1.30, 
              'jamon': 7.90}

# %%
def precio3(*args, **kwargs):
    total = []
    count = 0
    for k, v in kwargs.items():
        print("precio alimento" , kwargs[k])
        print("cantidad alimento", args[count])
        total.append(kwargs[k] * args[count])
        count += 1
    return sum(total)

# %%
precio3(2,1,0.5, 4,**diccionario)
# Out:
# precio alimento 1.5
# cantidad alimento 2
# precio alimento 4.5
# cantidad alimento 1
# precio alimento 1.3
# cantidad alimento 0.5
# precio alimento 7.9
# cantidad alimento 4
# 39.75

# %% [markdown]
# # Recursividad

# %% [markdown]
# Basicamente es una función que se llama a si misma

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def cuenta_atras(start):
    print(start)
    next_ = start - 1
    if next_ > 0:
        cuenta_atras(next_)

# %%
cuenta_atras(5)
# Out:
# 5
# 4
# 3
# 2
# 1
